# %%
import os
from docx import Document

# %%
def contains_table(docx_path):
    """Kiểm tra file DOCX có chứa bảng không"""
    try:
        doc = Document(docx_path)
        return len(doc.tables) > 0
    except Exception as e:
        print(f"Lỗi khi đọc file {docx_path}: {e}")
        return False

# %%
def find_docx_with_tables(root_folder):
    """Tìm và in các file DOCX có chứa bảng"""
    results = []
    
    for foldername, _, filenames in os.walk(root_folder):
        for filename in filenames:
            if filename.lower().endswith('.docx'):
                full_path = os.path.join(foldername, filename)
                
                if contains_table(full_path):
                    results.append(full_path)
                    print(f"Phát hiện bảng: {full_path}")
    
    return results

root_directory = "./data"  # THAY ĐỔI ĐƯỜNG DẪN NÀY
found_files = find_docx_with_tables(root_directory)
if found_files:
    for i, path in enumerate(found_files, 1):
        print(f"{i}. {path}")
else:
    print("Không tìm thấy file DOCX nào chứa bảng")
# Out:
# Không tìm thấy file DOCX nào chứa bảng

# %%
import os
import re
import time
from pathlib import Path
from docx import Document
from together import Together
from dotenv import load_dotenv


# Nạp biến môi trường từ file .env
load_dotenv()
api_key = os.getenv("TOGETHER_API_KEY")

client = Together(api_key=api_key)


# Prompt để chuyển đổi sang Markdown
CONVERSION_PROMPT = """
## Mục tiêu
Chuyển đổi tài liệu Word (.docx) sang định dạng Markdown theo template chuẩn tối ưu cho hệ thống RAG (Retrieval-Augmented Generation).

## Yêu cầu định dạng đầu ra

### Template chuẩn:
```markdown
# [TIÊU ĐỀ CHÍNH]

## [Mục lớn 1]
### [Tiểu mục 1.1]
- Nội dung chính...
- **Lưu ý**: Chi tiết quan trọng

### [Tiểu mục 1.2]
```code
Mã lệnh/command
```

## [Mục lớn 2]
| Cột 1 | Cột 2 | Mô tả |
|-------|-------|--------|
| A     | 100   | Chi tiết A |
| B     | 200   | Chi tiết B |
```

## Quy tắc chuyển đổi

### 1. Cấu trúc heading
- Tiêu đề chính: H1 (`#`)
- Heading cấp 1 trong Word → H2 (`##`)
- Heading cấp 2 trong Word → H3 (`###`)
- Heading cấp 3 trong Word → H4 (`####`)

### 2. Xử lý văn bản
- Giữ nguyên bold cho **thuật ngữ quan trọng**
- Chuyển italic thành _emphasis_
- Gạch dưới → **bold** nếu quan trọng, ngược lại bỏ
- Chữ màu/kích thước → bỏ định dạng

### 3. Danh sách
- List có số → đánh số thứ tự
- List không số → dấu gạch đầu dòng (`-`)
- List đa cấp: thụt lề 2 spaces cho mỗi cấp

### 4. Bảng biểu
```markdown
| Header 1 | Header 2 |
|----------|----------|
| Cell 1   | Cell 2   |
```
- Giữ nguyên số cột/hàng
- Căn trái mặc định

### 5. Hình ảnh
- Chuyển thành: `![Mô tả](path/to/image.jpg)`
- Lấy alt text từ Word, nếu không có → ghi "Hình minh họa"

### 6. Mã lệnh/cấu hình
Đặt trong code block với ngôn ngữ phù hợp:
```python
print("Hello World")
```

### 7. Liên kết
- Chuyển thành `[văn bản hiển thị](URL)`
- Nếu là email: `[tên](mailto:email@domain.com)`

## Xử lý đặc biệt
- Section ngăn cách: `---` (3 dấu gạch ngang)
- Ghi chú: `> Ghi chú quan trọng`
- Thuật ngữ: `**Thuật ngữ**: Định nghĩa`

## Yêu cầu chất lượng
- Không làm mất thông tin gốc
- Giữ nguyên cấu trúc phân cấp
- Đảm bảo cấu trúc phân cấp rõ ràng
- Giữ nguyên ngữ nghĩa nội dung, không thay đổi ý nghĩa

"""

def validate_markdown_structure(content):
    """Kiểm tra cấu trúc markdown"""
    errors = []
    
    # Kiểm tra tiêu đề chính
    if not re.search(r'^#\s+.+', content, re.MULTILINE):
        errors.append("Thiếu tiêu đề chính (H1)")
    
    # Kiểm tra tỷ lệ heading hợp lý
    h2_count = len(re.findall(r'^##\s+', content, re.MULTILINE))
    h3_count = len(re.findall(r'^###\s+', content, re.MULTILINE))
    
    if h3_count > 0 and h2_count == 0:
        errors.append("Có H3 nhưng thiếu H2")
    
    # Kiểm tra code block đóng mở đúng
    code_blocks = re.findall(r'```', content)
    if len(code_blocks) % 2 != 0:
        errors.append("Code block chưa đóng")
    
    return errors if errors else "Cấu trúc hợp lệ"

def extract_text_from_docx(docx_path):
    """Trích xuất text từ file DOCX"""
    try:
        doc = Document(docx_path)
        full_text = []
        
        for para in doc.paragraphs:
            text = para.text.strip()
            if text:
                full_text.append(text)
        
        content = "\n".join(full_text)
        return content
    except Exception as e:
        print(f"❌ Lỗi khi đọc file {docx_path}: {e}")
        return None

def convert_to_markdown_with_together(content, max_retries=3):
    """Chuyển đổi nội dung sang Markdown sử dụng Together AI"""
    
    for attempt in range(max_retries):
        try:
            print(f"🔄 Đang gọi Together AI (lần thử {attempt + 1}/{max_retries})...")
            
            response = client.chat.completions.create(
                model="meta-llama/Llama-3.3-70B-Instruct-Turbo-Free",
                messages=[
                    {"role": "system", "content": CONVERSION_PROMPT},
                    {"role": "user", "content": content}
                ],
                temperature=0
            )
            
            markdown_content = response.choices[0].message.content
            
            # Kiểm tra chất lượng markdown
            validation_errors = validate_markdown_structure(markdown_content)
            
            if isinstance(validation_errors, list) and len(validation_errors) > 0:
                print(f"⚠️  Lần thử {attempt + 1}: Markdown chưa hợp lệ - {validation_errors}")
                if attempt < max_retries - 1:
                    time.sleep(2)  # Đợi 2 giây trước khi thử lại
                    continue
                else:
                    print("⚠️  Đã thử tối đa, sử dụng kết quả cuối cùng")
            else:
                print(f"✅ Lần thử {attempt + 1}: Markdown hợp lệ!")
                return markdown_content
            
        except Exception as e:
            print(f"❌ Lỗi khi gọi Together AI (lần thử {attempt + 1}): {e}")
            if attempt < max_retries - 1:
                time.sleep(2)
                continue
            else:
                print("❌ Đã thử tối đa, không thành công")
                return None
    
    return markdown_content if 'markdown_content' in locals() else None

def find_all_docx_files(folder_path):
    """Tìm tất cả file DOCX trong folder và subfolder"""
    docx_files = []
    folder_path = Path(folder_path)
    
    print(f"🔍 Đang tìm file DOCX trong: {folder_path}")
    
    for file_path in folder_path.rglob("*.docx"):
        # Bỏ qua file tạm của Office (bắt đầu bằng ~$)
        if not file_path.name.startswith("~$"):
            docx_files.append(file_path)
            print(f"📄 Tìm thấy: {file_path}")
    
    print(f"📊 Tổng cộng tìm thấy {len(docx_files)} file DOCX")
    return docx_files

def generate_output_path(docx_path, input_folder, output_folder):
    """Tạo đường dẫn output tương ứng với cấu trúc folder và lưu tên file dạng 'đường_dẫn_tên_file.md'"""
    docx_path = Path(docx_path)
    input_folder = Path(input_folder)
    output_folder = Path(output_folder)
    
    # Tính toán đường dẫn tương đối
    relative_path = docx_path.relative_to(input_folder)
    
    # Chuyển đường dẫn tương đối thành đường dẫn chuỗi
    relative_path_str = str(relative_path).replace(os.sep, '_')
    
    # Tạo đường dẫn output với tên file dạng đường_dẫn_tên_file.md
    output_path = output_folder / f"{relative_path_str}.md"
    
    return output_path


def process_docx_files(input_folder, output_folder):
    """Xử lý tất cả file DOCX trong folder"""
    
    # Tạo thư mục output nếu chưa tồn tại
    output_folder = Path(output_folder)
    output_folder.mkdir(parents=True, exist_ok=True)
    
    # Tìm tất cả file DOCX
    docx_files = find_all_docx_files(input_folder)
    
    if not docx_files:
        print("❌ Không tìm thấy file DOCX nào!")
        return
    
    successful_conversions = 0
    failed_conversions = 0
    
    for i, docx_file in enumerate(docx_files, 1):
        print(f"\n{'='*60}")
        print(f"🔄 Đang xử lý file {i}/{len(docx_files)}: {docx_file.name}")
        print(f"{'='*60}")
        
        # Tạo đường dẫn output
        output_path = generate_output_path(docx_file, input_folder, output_folder)
        
        # Tạo thư mục con nếu cần
        output_path.parent.mkdir(parents=True, exist_ok=True)
        
        print(f"📂 Đường dẫn đầu vào: {docx_file}")
        print(f"📁 Đường dẫn đầu ra: {output_path}")
        
        # Trích xuất nội dung từ DOCX
        print("📖 Đang đọc nội dung DOCX...")
        content = extract_text_from_docx(docx_file)
        
        if content is None:
            print("❌ Không thể đọc file DOCX")
            failed_conversions += 1
            continue
        
        print(f"📝 Đã đọc {len(content)} ký tự")
        
        # Chuyển đổi sang Markdown
        print("🤖 Đang chuyển đổi sang Markdown...")
        markdown_content = convert_to_markdown_with_together(content)
        
        if markdown_content is None:
            print("❌ Không thể chuyển đổi sang Markdown")
            failed_conversions += 1
            continue
        
        # Lưu file Markdown
        try:
            with open(output_path, 'w', encoding='utf-8') as f:
                f.write(markdown_content)
            print(f"✅ Đã lưu thành công: {output_path}")
            successful_conversions += 1
        except Exception as e:
            print(f"❌ Lỗi khi lưu file: {e}")
            failed_conversions += 1
    
    # Báo cáo kết quả
    print(f"\n{'='*60}")
    print("📊 KẾT QUẢ TỔNG KẾT:")
    print(f"✅ Thành công: {successful_conversions} file")
    print(f"❌ Thất bại: {failed_conversions} file")
    print(f"📁 Thư mục output: {output_folder}")
    print(f"{'='*60}")

def check_markdown_files_in_folder(folder_path):
    """Kiểm tra tất cả file Markdown trong folder"""
    result = {}
    folder_path = Path(folder_path)
    
    print(f"\n🔍 Đang kiểm tra file Markdown trong: {folder_path}")
    
    for md_file in folder_path.rglob("*.md"):
        try:
            with open(md_file, 'r', encoding='utf-8') as file:
                content = file.read()
                validation_result = validate_markdown_structure(content)
                result[str(md_file.relative_to(folder_path))] = validation_result
        except Exception as e:
            result[str(md_file.relative_to(folder_path))] = f"Lỗi khi đọc file: {e}"
    
    return result




input_folder = './data'
output_folder  = './markdown'


def main():
    """Hàm chính"""
    print("🚀 DOCX to Markdown Converter với Together AI")
    print("="*60)
    
    # Cấu hình đường dẫn
    input_folder = './data'
    output_folder  = './md_ai'
    
    if not output_folder:
        output_folder = "./md_ai"
    
    # Kiểm tra folder input
    if not os.path.exists(input_folder):
        print(f"❌ Folder không tồn tại: {input_folder}")
        return
    
    # Xử lý chuyển đổi
    process_docx_files(input_folder, output_folder)
    
    # Kiểm tra kết quả
    print("\n🔍 Đang kiểm tra chất lượng file Markdown...")
    validation_results = check_markdown_files_in_folder(output_folder)
    
    if validation_results:
        print("\n📋 KẾT QUẢ KIỂM TRA:")
        for filename, result in validation_results.items():
            print(f"\n📄 File: {filename}")
            if isinstance(result, list):
                for error in result:
                    print(f"  ⚠️  {error}")
            else:
                print(f"  ✅ {result}")
    else:
        print("❌ Không tìm thấy file Markdown nào để kiểm tra")

if __name__ == "__main__":
    main()
# Out:
# 🚀 DOCX to Markdown Converter với Together AI
# ============================================================
# 🔍 Đang tìm file DOCX trong: data
# 📄 Tìm thấy: data/4. Thông tin các khoa/THÔNG TIN CÁC KHOA - VĂN PHÒNG ĐÀO TẠO.docx
# 📄 Tìm thấy: data/2. Tờ rơi các ngành đào tạo/Mẫu Thông tin về ngành Kinh doanh số.docx
# 📄 Tìm thấy: data/2. Tờ rơi các ngành đào tạo/QUẢN LÝ CÔNG NGHIỆP.docx
# 📄 Tìm thấy: data/2. Tờ rơi các ngành đào tạo/KỸ THUẬT VẬT LIỆU.docx
# 📄 Tìm thấy: data/2. Tờ rơi các ngành đào tạo/PFIEV.docx
# 📄 Tìm thấy: data/1. Thông tin Tuyển sinh 2025/11.05.25-HCMUT-Thông tin tuyển sinh Đại học chính quy năm 2025.docx
# 📄 Tìm thấy: data/5. Thông tin PTN-xưởng/Thông tin PTN_Xưởng.docx
# 📄 Tìm thấy: data/3. Thông tin Lãnh đạo các đơn vị/Thông tin Lãnh đạo các đơn vị.docx
# 📄 Tìm thấy: data/2. Tờ rơi các ngành đào tạo/CƠ KHÍ/KỸ THUẬT CƠ KHÍ.docx
# 📄 Tìm thấy: data/2. Tờ rơi các ngành đào tạo/CƠ KHÍ/KỸ THUẬT CƠ ĐIỆN TỬ.docx
# 📄 Tìm thấy: data/2. Tờ rơi các ngành đào tạo/CƠ KHÍ/KỸ THUẬT NHIỆT.docx
# 📄 Tìm thấy: data/2. Tờ rơi các ngành đào tạo/CƠ KHÍ/KỸ THUẬT DỆT, CÔNG NGHỆ DỆT, MAY.docx
# 📄 Tìm thấy: data/2. Tờ rơi các ngành đào tạo/CƠ KHÍ/BẢO DƯỠNG CÔNG NGHIỆP.docx
# 📄 Tìm thấy: data/2. Tờ rơi các ngành đào tạo/CƠ KHÍ/LOGISTIC VÀ HỆ THỐNG CÔNG NGHIỆP.docx
# 📄 Tìm thấy: data/2. Tờ rơi các ngành đào tạo/ĐIỆN - ĐIỆN TỬ/ĐIỀU KHIỂN VÀ TỰ ĐỘNG HÓA.docx
# 📄 Tìm thấy: data/2. Tờ rơi các ngành đào tạo/ĐIỆN - ĐIỆN TỬ/ĐIỆN TỬ - VIỄN THÔNG.docx
# 📄 Tìm thấy: data/2. Tờ rơi các ngành đào tạo/ĐIỆN - ĐIỆN TỬ/THIẾT KẾ VI MẠCH.docx
# 📄 Tìm thấy: data/2. Tờ rơi các ngành đào tạo/ĐIỆN - ĐIỆN TỬ/KỸ THUẬT ĐIỆN.docx
# 📄 Tìm thấy: data/2. Tờ rơi các ngành đào tạo/KHOA KỸ THUẬT GIAO THÔNG/KỸ THUẬT HÀNG KHÔNG.docx
# 📄 Tìm thấy: data/2. Tờ rơi các ngành đào tạo/KHOA KỸ THUẬT GIAO THÔNG/KỸ THUẬT Ô TÔ.docx
# 📄 Tìm thấy: data/2. Tờ rơi các ngành đào tạo/KHOA KỸ THUẬT GIAO THÔNG/KỸ THUẬT TÀU THỦY.docx
# 📄 Tìm thấy: data/2. Tờ rơi các ngành đào tạo/ĐỊA CHẤT VÀ DẦU KHÍ/ĐỊA KỸ THUẬT XÂY DỰNG.docx
# 📄 Tìm thấy: data/2. Tờ rơi các ngành đào tạo/ĐỊA CHẤT VÀ DẦU KHÍ/ĐỊA CHẤT - DẦU KHÍ.docx
# 📄 Tìm thấy: data/2. Tờ rơi các ngành đào tạo/KỸ THUẬT HÓA HỌC/CÔNG NGHỆ SINH HỌC.docx
# 📄 Tìm thấy: data/2. Tờ rơi các ngành đào tạo/KỸ THUẬT HÓA HỌC/CÔNG NGHỆ THỰC PHẨM.docx
# 📄 Tìm thấy: data/2. Tờ rơi các ngành đào tạo/KỸ THUẬT HÓA HỌC/KỸ THUẬT HÓA HỌC.docx
# 📄 Tìm thấy: data/2. Tờ rơi các ngành đào tạo/TÀI NGUYÊN VÀ MÔI TRƯỜNG/QUẢN LÝ TÀI NGUYÊN VÀ MÔI TRƯỜNG.docx
# 📄 Tìm thấy: data/2. Tờ rơi các ngành đào tạo/TÀI NGUYÊN VÀ MÔI TRƯỜNG/KỸ THUẬT MÔI TRƯỜNG.docx
# 📄 Tìm thấy: data/2. Tờ rơi các ngành đào tạo/KHOA KỸ THUẬT XÂY DỰNG/KỸ THUẬT VÀ QUẢN LÝ NƯỚC ĐÔ THỊ.docx
# 📄 Tìm thấy: data/2. Tờ rơi các ngành đào tạo/KHOA KỸ THUẬT XÂY DỰNG/KỸ THUẬT XÂY DỰNG CƠ SỞ HẠ TẦNG.docx
# 📄 Tìm thấy: data/2. Tờ rơi các ngành đào tạo/KHOA KỸ THUẬT XÂY DỰNG/CÔNG NGHỆ KỸ THUẬT VẬT LIỆU XÂY DỰNG.docx
# 📄 Tìm thấy: data/2. Tờ rơi các ngành đào tạo/KHOA KỸ THUẬT XÂY DỰNG/KIẾN TRÚC.docx
# 📄 Tìm thấy: data/2. Tờ rơi các ngành đào tạo/KHOA KỸ THUẬT XÂY DỰNG/KỸ THUẬT XÂY DỰNG CÔNG TRÌNH BIỂN.docx
# 📄 Tìm thấy: data/2. Tờ rơi các ngành đào tạo/KHOA KỸ THUẬT XÂY DỰNG/KỸ THUẬT XÂY DỰNG CÔNG TRÌNH GIAO THÔNG.docx
# 📄 Tìm thấy: data/2. Tờ rơi các ngành đào tạo/KHOA KỸ THUẬT XÂY DỰNG/KINH TẾ XÂY DỰNG.docx
# 📄 Tìm thấy: data/2. Tờ rơi các ngành đào tạo/KHOA KỸ THUẬT XÂY DỰNG/XÂY DỰNG DÂN DỤNG - CÔNG NGHIỆP VÀ HIỆU QUẢ NĂNG LƯỢNG.docx
# 📄 Tìm thấy: data/2. Tờ rơi các ngành đào tạo/KHOA KỸ THUẬT XÂY DỰNG/KỸ THUẬT XÂY DỰNG.docx
# 📄 Tìm thấy: data/2. Tờ rơi các ngành đào tạo/KHOA HỌC ỨNG DỤNG/KHOA HỌC DỮ LIỆU.docx
# 📄 Tìm thấy: data/2. Tờ rơi các ngành đào tạo/KHOA HỌC ỨNG DỤNG/CƠ KỸ THUẬT.docx
# 📄 Tìm thấy: data/2. Tờ rơi các ngành đào tạo/KHOA HỌC ỨNG DỤNG/VẬT LÝ KỸ THUẬT.docx
# 📄 Tìm thấy: data/2. Tờ rơi các ngành đào tạo/KHOA HỌC VÀ KỸ THUẬT MÁY TÍNH/KỸ THUẬT MÁY TÍNH.docx
# 📄 Tìm thấy: data/2. Tờ rơi các ngành đào tạo/KHOA HỌC VÀ KỸ THUẬT MÁY TÍNH/KHOA HỌC MÁY TÍNH.docx
# 📊 Tổng cộng tìm thấy 42 file DOCX
#
# ============================================================
# 🔄 Đang xử lý file 1/42: THÔNG TIN CÁC KHOA - VĂN PHÒNG ĐÀO TẠO.docx
# ============================================================
# 📂 Đường dẫn đầu vào: data/4. Thông tin các khoa/THÔNG TIN CÁC KHOA - VĂN PHÒNG ĐÀO TẠO.docx
# 📁 Đường dẫn đầu ra: md_ai/4. Thông tin các khoa_THÔNG TIN CÁC KHOA - VĂN PHÒNG ĐÀO TẠO.docx.md
# 📖 Đang đọc nội dung DOCX...
# 📝 Đã đọc 26963 ký tự
# 🤖 Đang chuyển đổi sang Markdown...
# 🔄 Đang gọi Together AI (lần thử 1/3)...
# ❌ Lỗi khi gọi Together AI (lần thử 1): Error code: 422 - {"message": "Input validation error: `inputs` tokens + `max_new_tokens` must be <= 8193. Given: 9880 `inputs` tokens and 2048 `max_new_tokens`", "type_": "invalid_request_error"}
# 🔄 Đang gọi Together AI (lần thử 2/3)...
# ❌ Lỗi khi gọi Together AI (lần thử 2): Error code: 422 - {"message": "Input validation error: `inputs` tokens + `max_new_tokens` must be <= 8193. Given: 9880 `inputs` tokens and 2048 `max_new_tokens`", "type_": "invalid_request_error"}
# 🔄 Đang gọi Together AI (lần thử 3/3)...
# ❌ Lỗi khi gọi Together AI (lần thử 3): Error code: 422 - {"message": "Input validation error: `inputs` tokens + `max_new_tokens` must be <= 8193. Given: 9880 `inputs` tokens and 2048 `max_new_tokens`", "type_": "invalid_request_error"}
# ❌ Đã thử tối đa, không thành công
# ❌ Không thể chuyển đổi sang Markdown
#
# ============================================================
# 🔄 Đang xử lý file 2/42: Mẫu Thông tin về ngành Kinh doanh số.docx
# ============================================================
# 📂 Đường dẫn đầu vào: data/2. Tờ rơi các ngành đào tạo/Mẫu Thông tin về ngành Kinh doanh số.docx
# 📁 Đường dẫn đầu ra: md_ai/2. Tờ rơi các ngành đào tạo_Mẫu Thông tin về ngành Kinh doanh số.docx.md
# 📖 Đang đọc nội dung DOCX...
# 📝 Đã đọc 1374 ký tự
# 🤖 Đang chuyển đổi sang Markdown...
# 🔄 Đang gọi Together AI (lần thử 1/3)...
# ✅ Lần thử 1: Markdown hợp lệ!
# ✅ Đã lưu thành công: md_ai/2. Tờ rơi các ngành đào tạo_Mẫu Thông tin về ngành Kinh doanh số.docx.md
#
# ============================================================
# 🔄 Đang xử lý file 3/42: QUẢN LÝ CÔNG NGHIỆP.docx
# ============================================================
# 📂 Đường dẫn đầu vào: data/2. Tờ rơi các ngành đào tạo/QUẢN LÝ CÔNG NGHIỆP.docx
# 📁 Đường dẫn đầu ra: md_ai/2. Tờ rơi các ngành đào tạo_QUẢN LÝ CÔNG NGHIỆP.docx.md
# 📖 Đang đọc nội dung DOCX...
# 📝 Đã đọc 4873 ký tự
# 🤖 Đang chuyển đổi sang Markdown...
# 🔄 Đang gọi Together AI (lần thử 1/3)...
# ✅ Lần thử 1: Markdown hợp lệ!
# ✅ Đã lưu thành công: md_ai/2. Tờ rơi các ngành đào tạo_QUẢN LÝ CÔNG NGHIỆP.docx.md
#
# ============================================================
# 🔄 Đang xử lý file 4/42: KỸ THUẬT VẬT LIỆU.docx
# ============================================================
# 📂 Đường dẫn đầu vào: data/2. Tờ rơi các ngành đào tạo/KỸ THUẬT VẬT LIỆU.docx
# 📁 Đường dẫn đầu ra: md_ai/2. Tờ rơi các ngành đào tạo_KỸ THUẬT VẬT LIỆU.docx.md
# 📖 Đang đọc nội dung DOCX...
# 📝 Đã đọc 5221 ký tự
# 🤖 Đang chuyển đổi sang Markdown...
# 🔄 Đang gọi Together AI (lần thử 1/3)...
# ✅ Lần thử 1: Markdown hợp lệ!
# ✅ Đã lưu thành công: md_ai/2. Tờ rơi các ngành đào tạo_KỸ THUẬT VẬT LIỆU.docx.md
#
# ============================================================
# 🔄 Đang xử lý file 5/42: PFIEV.docx
# ============================================================
# 📂 Đường dẫn đầu vào: data/2. Tờ rơi các ngành đào tạo/PFIEV.docx
# 📁 Đường dẫn đầu ra: md_ai/2. Tờ rơi các ngành đào tạo_PFIEV.docx.md
# 📖 Đang đọc nội dung DOCX...
# 📝 Đã đọc 3830 ký tự
# 🤖 Đang chuyển đổi sang Markdown...
# 🔄 Đang gọi Together AI (lần thử 1/3)...
# ✅ Lần thử 1: Markdown hợp lệ!
# ✅ Đã lưu thành công: md_ai/2. Tờ rơi các ngành đào tạo_PFIEV.docx.md
#
# ============================================================
# 🔄 Đang xử lý file 6/42: 11.05.25-HCMUT-Thông tin tuyển sinh Đại học chính quy năm 2025.docx
# ============================================================
# 📂 Đường dẫn đầu vào: data/1. Thông tin Tuyển sinh 2025/11.05.25-HCMUT-Thông tin tuyển sinh Đại học chính quy năm 2025.docx
# 📁 Đường dẫn đầu ra: md_ai/1. Thông tin Tuyển sinh 2025_11.05.25-HCMUT-Thông tin tuyển sinh Đại học chính quy năm 2025.docx.md
# 📖 Đang đọc nội dung DOCX...
# 📝 Đã đọc 36704 ký tự
# 🤖 Đang chuyển đổi sang Markdown...
# 🔄 Đang gọi Together AI (lần thử 1/3)...
# ❌ Lỗi khi gọi Together AI (lần thử 1): Error code: 422 - {"message": "Input validation error: `inputs` tokens + `max_new_tokens` must be <= 8193. Given: 13160 `inputs` tokens and 2048 `max_new_tokens`", "type_": "invalid_request_error"}
# 🔄 Đang gọi Together AI (lần thử 2/3)...
# ❌ Lỗi khi gọi Together AI (lần thử 2): Error code: 422 - {"message": "Input validation error: `inputs` tokens + `max_new_tokens` must be <= 8193. Given: 13160 `inputs` tokens and 2048 `max_new_tokens`", "type_": "invalid_request_error"}
# 🔄 Đang gọi Together AI (lần thử 3/3)...
# ❌ Lỗi khi gọi Together AI (lần thử 3): Error code: 422 - {"message": "Input validation error: `inputs` tokens + `max_new_tokens` must be <= 8193. Given: 13160 `inputs` tokens and 2048 `max_new_tokens`", "type_": "invalid_request_error"}
# ❌ Đã thử tối đa, không thành công
# ❌ Không thể chuyển đổi sang Markdown
#
# ============================================================
# 🔄 Đang xử lý file 7/42: Thông tin PTN_Xưởng.docx
# ============================================================
# 📂 Đường dẫn đầu vào: data/5. Thông tin PTN-xưởng/Thông tin PTN_Xưởng.docx
# 📁 Đường dẫn đầu ra: md_ai/5. Thông tin PTN-xưởng_Thông tin PTN_Xưởng.docx.md
# 📖 Đang đọc nội dung DOCX...
# 📝 Đã đọc 5196 ký tự
# 🤖 Đang chuyển đổi sang Markdown...
# 🔄 Đang gọi Together AI (lần thử 1/3)...
# ✅ Lần thử 1: Markdown hợp lệ!
# ✅ Đã lưu thành công: md_ai/5. Thông tin PTN-xưởng_Thông tin PTN_Xưởng.docx.md
#
# ============================================================
# 🔄 Đang xử lý file 8/42: Thông tin Lãnh đạo các đơn vị.docx
# ============================================================
# 📂 Đường dẫn đầu vào: data/3. Thông tin Lãnh đạo các đơn vị/Thông tin Lãnh đạo các đơn vị.docx
# 📁 Đường dẫn đầu ra: md_ai/3. Thông tin Lãnh đạo các đơn vị_Thông tin Lãnh đạo các đơn vị.docx.md
# 📖 Đang đọc nội dung DOCX...
# 📝 Đã đọc 17913 ký tự
# 🤖 Đang chuyển đổi sang Markdown...
# 🔄 Đang gọi Together AI (lần thử 1/3)...
# ❌ Lỗi khi gọi Together AI (lần thử 1): Error code: 422 - {"message": "Input validation error: `inputs` tokens + `max_new_tokens` must be <= 8193. Given: 6840 `inputs` tokens and 2048 `max_new_tokens`", "type_": "invalid_request_error"}
# 🔄 Đang gọi Together AI (lần thử 2/3)...
# ❌ Lỗi khi gọi Together AI (lần thử 2): Error code: 422 - {"message": "Input validation error: `inputs` tokens + `max_new_tokens` must be <= 8193. Given: 6840 `inputs` tokens and 2048 `max_new_tokens`", "type_": "invalid_request_error"}
# 🔄 Đang gọi Together AI (lần thử 3/3)...
# ❌ Lỗi khi gọi Together AI (lần thử 3): Error code: 422 - {"message": "Input validation error: `inputs` tokens + `max_new_tokens` must be <= 8193. Given: 6840 `inputs` tokens and 2048 `max_new_tokens`", "type_": "invalid_request_error"}
# ❌ Đã thử tối đa, không thành công
# ❌ Không thể chuyển đổi sang Markdown
#
# ============================================================
# 🔄 Đang xử lý file 9/42: KỸ THUẬT CƠ KHÍ.docx
# ============================================================
# 📂 Đường dẫn đầu vào: data/2. Tờ rơi các ngành đào tạo/CƠ KHÍ/KỸ THUẬT CƠ KHÍ.docx
# 📁 Đường dẫn đầu ra: md_ai/2. Tờ rơi các ngành đào tạo_CƠ KHÍ_KỸ THUẬT CƠ KHÍ.docx.md
# 📖 Đang đọc nội dung DOCX...
# 📝 Đã đọc 3877 ký tự
# 🤖 Đang chuyển đổi sang Markdown...
# 🔄 Đang gọi Together AI (lần thử 1/3)...
# ✅ Lần thử 1: Markdown hợp lệ!
# ✅ Đã lưu thành công: md_ai/2. Tờ rơi các ngành đào tạo_CƠ KHÍ_KỸ THUẬT CƠ KHÍ.docx.md
#
# ============================================================
# 🔄 Đang xử lý file 10/42: KỸ THUẬT CƠ ĐIỆN TỬ.docx
# ============================================================
# 📂 Đường dẫn đầu vào: data/2. Tờ rơi các ngành đào tạo/CƠ KHÍ/KỸ THUẬT CƠ ĐIỆN TỬ.docx
# 📁 Đường dẫn đầu ra: md_ai/2. Tờ rơi các ngành đào tạo_CƠ KHÍ_KỸ THUẬT CƠ ĐIỆN TỬ.docx.md
# 📖 Đang đọc nội dung DOCX...
# 📝 Đã đọc 3689 ký tự
# 🤖 Đang chuyển đổi sang Markdown...
# 🔄 Đang gọi Together AI (lần thử 1/3)...
# ✅ Lần thử 1: Markdown hợp lệ!
# ✅ Đã lưu thành công: md_ai/2. Tờ rơi các ngành đào tạo_CƠ KHÍ_KỸ THUẬT CƠ ĐIỆN TỬ.docx.md
#
# ============================================================
# 🔄 Đang xử lý file 11/42: KỸ THUẬT NHIỆT.docx
# ============================================================
# 📂 Đường dẫn đầu vào: data/2. Tờ rơi các ngành đào tạo/CƠ KHÍ/KỸ THUẬT NHIỆT.docx
# 📁 Đường dẫn đầu ra: md_ai/2. Tờ rơi các ngành đào tạo_CƠ KHÍ_KỸ THUẬT NHIỆT.docx.md
# 📖 Đang đọc nội dung DOCX...
# 📝 Đã đọc 2534 ký tự
# 🤖 Đang chuyển đổi sang Markdown...
# 🔄 Đang gọi Together AI (lần thử 1/3)...
# ✅ Lần thử 1: Markdown hợp lệ!
# ✅ Đã lưu thành công: md_ai/2. Tờ rơi các ngành đào tạo_CƠ KHÍ_KỸ THUẬT NHIỆT.docx.md
#
# ============================================================
# 🔄 Đang xử lý file 12/42: KỸ THUẬT DỆT, CÔNG NGHỆ DỆT, MAY.docx
# ============================================================
# 📂 Đường dẫn đầu vào: data/2. Tờ rơi các ngành đào tạo/CƠ KHÍ/KỸ THUẬT DỆT, CÔNG NGHỆ DỆT, MAY.docx
# 📁 Đường dẫn đầu ra: md_ai/2. Tờ rơi các ngành đào tạo_CƠ KHÍ_KỸ THUẬT DỆT, CÔNG NGHỆ DỆT, MAY.docx.md
# 📖 Đang đọc nội dung DOCX...
# 📝 Đã đọc 4789 ký tự
# 🤖 Đang chuyển đổi sang Markdown...
# 🔄 Đang gọi Together AI (lần thử 1/3)...
# ✅ Lần thử 1: Markdown hợp lệ!
# ✅ Đã lưu thành công: md_ai/2. Tờ rơi các ngành đào tạo_CƠ KHÍ_KỸ THUẬT DỆT, CÔNG NGHỆ DỆT, MAY.docx.md
#
# ============================================================
# 🔄 Đang xử lý file 13/42: BẢO DƯỠNG CÔNG NGHIỆP.docx
# ============================================================
# 📂 Đường dẫn đầu vào: data/2. Tờ rơi các ngành đào tạo/CƠ KHÍ/BẢO DƯỠNG CÔNG NGHIỆP.docx
# 📁 Đường dẫn đầu ra: md_ai/2. Tờ rơi các ngành đào tạo_CƠ KHÍ_BẢO DƯỠNG CÔNG NGHIỆP.docx.md
# 📖 Đang đọc nội dung DOCX...
# 📝 Đã đọc 3290 ký tự
# 🤖 Đang chuyển đổi sang Markdown...
# 🔄 Đang gọi Together AI (lần thử 1/3)...
# ✅ Lần thử 1: Markdown hợp lệ!
# ✅ Đã lưu thành công: md_ai/2. Tờ rơi các ngành đào tạo_CƠ KHÍ_BẢO DƯỠNG CÔNG NGHIỆP.docx.md
#
# ============================================================
# 🔄 Đang xử lý file 14/42: LOGISTIC VÀ HỆ THỐNG CÔNG NGHIỆP.docx
# ============================================================
# 📂 Đường dẫn đầu vào: data/2. Tờ rơi các ngành đào tạo/CƠ KHÍ/LOGISTIC VÀ HỆ THỐNG CÔNG NGHIỆP.docx
# 📁 Đường dẫn đầu ra: md_ai/2. Tờ rơi các ngành đào tạo_CƠ KHÍ_LOGISTIC VÀ HỆ THỐNG CÔNG NGHIỆP.docx.md
# 📖 Đang đọc nội dung DOCX...
# 📝 Đã đọc 5800 ký tự
# 🤖 Đang chuyển đổi sang Markdown...
# 🔄 Đang gọi Together AI (lần thử 1/3)...
# ✅ Lần thử 1: Markdown hợp lệ!
# ✅ Đã lưu thành công: md_ai/2. Tờ rơi các ngành đào tạo_CƠ KHÍ_LOGISTIC VÀ HỆ THỐNG CÔNG NGHIỆP.docx.md
#
# ============================================================
# 🔄 Đang xử lý file 15/42: ĐIỀU KHIỂN VÀ TỰ ĐỘNG HÓA.docx
# ============================================================
# 📂 Đường dẫn đầu vào: data/2. Tờ rơi các ngành đào tạo/ĐIỆN - ĐIỆN TỬ/ĐIỀU KHIỂN VÀ TỰ ĐỘNG HÓA.docx
# 📁 Đường dẫn đầu ra: md_ai/2. Tờ rơi các ngành đào tạo_ĐIỆN - ĐIỆN TỬ_ĐIỀU KHIỂN VÀ TỰ ĐỘNG HÓA.docx.md
# 📖 Đang đọc nội dung DOCX...
# 📝 Đã đọc 2454 ký tự
# 🤖 Đang chuyển đổi sang Markdown...
# 🔄 Đang gọi Together AI (lần thử 1/3)...
# ✅ Lần thử 1: Markdown hợp lệ!
# ✅ Đã lưu thành công: md_ai/2. Tờ rơi các ngành đào tạo_ĐIỆN - ĐIỆN TỬ_ĐIỀU KHIỂN VÀ TỰ ĐỘNG HÓA.docx.md
#
# ============================================================
# 🔄 Đang xử lý file 16/42: ĐIỆN TỬ - VIỄN THÔNG.docx
# ============================================================
# 📂 Đường dẫn đầu vào: data/2. Tờ rơi các ngành đào tạo/ĐIỆN - ĐIỆN TỬ/ĐIỆN TỬ - VIỄN THÔNG.docx
# 📁 Đường dẫn đầu ra: md_ai/2. Tờ rơi các ngành đào tạo_ĐIỆN - ĐIỆN TỬ_ĐIỆN TỬ - VIỄN THÔNG.docx.md
# 📖 Đang đọc nội dung DOCX...
# 📝 Đã đọc 5601 ký tự
# 🤖 Đang chuyển đổi sang Markdown...
# 🔄 Đang gọi Together AI (lần thử 1/3)...
# ✅ Lần thử 1: Markdown hợp lệ!
# ✅ Đã lưu thành công: md_ai/2. Tờ rơi các ngành đào tạo_ĐIỆN - ĐIỆN TỬ_ĐIỆN TỬ - VIỄN THÔNG.docx.md
#
# ============================================================
# 🔄 Đang xử lý file 17/42: THIẾT KẾ VI MẠCH.docx
# ============================================================
# 📂 Đường dẫn đầu vào: data/2. Tờ rơi các ngành đào tạo/ĐIỆN - ĐIỆN TỬ/THIẾT KẾ VI MẠCH.docx
# 📁 Đường dẫn đầu ra: md_ai/2. Tờ rơi các ngành đào tạo_ĐIỆN - ĐIỆN TỬ_THIẾT KẾ VI MẠCH.docx.md
# 📖 Đang đọc nội dung DOCX...
# 📝 Đã đọc 4497 ký tự
# 🤖 Đang chuyển đổi sang Markdown...
# 🔄 Đang gọi Together AI (lần thử 1/3)...
# ✅ Lần thử 1: Markdown hợp lệ!
# ✅ Đã lưu thành công: md_ai/2. Tờ rơi các ngành đào tạo_ĐIỆN - ĐIỆN TỬ_THIẾT KẾ VI MẠCH.docx.md
#
# ============================================================
# 🔄 Đang xử lý file 18/42: KỸ THUẬT ĐIỆN.docx
# ============================================================
# 📂 Đường dẫn đầu vào: data/2. Tờ rơi các ngành đào tạo/ĐIỆN - ĐIỆN TỬ/KỸ THUẬT ĐIỆN.docx
# 📁 Đường dẫn đầu ra: md_ai/2. Tờ rơi các ngành đào tạo_ĐIỆN - ĐIỆN TỬ_KỸ THUẬT ĐIỆN.docx.md
# 📖 Đang đọc nội dung DOCX...
# 📝 Đã đọc 6656 ký tự
# 🤖 Đang chuyển đổi sang Markdown...
# 🔄 Đang gọi Together AI (lần thử 1/3)...
# ✅ Lần thử 1: Markdown hợp lệ!
# ✅ Đã lưu thành công: md_ai/2. Tờ rơi các ngành đào tạo_ĐIỆN - ĐIỆN TỬ_KỸ THUẬT ĐIỆN.docx.md
#
# ============================================================
# 🔄 Đang xử lý file 19/42: KỸ THUẬT HÀNG KHÔNG.docx
# ============================================================
# 📂 Đường dẫn đầu vào: data/2. Tờ rơi các ngành đào tạo/KHOA KỸ THUẬT GIAO THÔNG/KỸ THUẬT HÀNG KHÔNG.docx
# 📁 Đường dẫn đầu ra: md_ai/2. Tờ rơi các ngành đào tạo_KHOA KỸ THUẬT GIAO THÔNG_KỸ THUẬT HÀNG KHÔNG.docx.md
# 📖 Đang đọc nội dung DOCX...
# 📝 Đã đọc 4794 ký tự
# 🤖 Đang chuyển đổi sang Markdown...
# 🔄 Đang gọi Together AI (lần thử 1/3)...
# ✅ Lần thử 1: Markdown hợp lệ!
# ✅ Đã lưu thành công: md_ai/2. Tờ rơi các ngành đào tạo_KHOA KỸ THUẬT GIAO THÔNG_KỸ THUẬT HÀNG KHÔNG.docx.md
#
# ============================================================
# 🔄 Đang xử lý file 20/42: KỸ THUẬT Ô TÔ.docx
# ============================================================
# 📂 Đường dẫn đầu vào: data/2. Tờ rơi các ngành đào tạo/KHOA KỸ THUẬT GIAO THÔNG/KỸ THUẬT Ô TÔ.docx
# 📁 Đường dẫn đầu ra: md_ai/2. Tờ rơi các ngành đào tạo_KHOA KỸ THUẬT GIAO THÔNG_KỸ THUẬT Ô TÔ.docx.md
# 📖 Đang đọc nội dung DOCX...
# 📝 Đã đọc 4763 ký tự
# 🤖 Đang chuyển đổi sang Markdown...
# 🔄 Đang gọi Together AI (lần thử 1/3)...
# ✅ Lần thử 1: Markdown hợp lệ!
# ✅ Đã lưu thành công: md_ai/2. Tờ rơi các ngành đào tạo_KHOA KỸ THUẬT GIAO THÔNG_KỸ THUẬT Ô TÔ.docx.md
#
# ============================================================
# 🔄 Đang xử lý file 21/42: KỸ THUẬT TÀU THỦY.docx
# ============================================================
# 📂 Đường dẫn đầu vào: data/2. Tờ rơi các ngành đào tạo/KHOA KỸ THUẬT GIAO THÔNG/KỸ THUẬT TÀU THỦY.docx
# 📁 Đường dẫn đầu ra: md_ai/2. Tờ rơi các ngành đào tạo_KHOA KỸ THUẬT GIAO THÔNG_KỸ THUẬT TÀU THỦY.docx.md
# 📖 Đang đọc nội dung DOCX...
# 📝 Đã đọc 3683 ký tự
# 🤖 Đang chuyển đổi sang Markdown...
# 🔄 Đang gọi Together AI (lần thử 1/3)...
# ✅ Lần thử 1: Markdown hợp lệ!
# ✅ Đã lưu thành công: md_ai/2. Tờ rơi các ngành đào tạo_KHOA KỸ THUẬT GIAO THÔNG_KỸ THUẬT TÀU THỦY.docx.md
#
# ============================================================
# 🔄 Đang xử lý file 22/42: ĐỊA KỸ THUẬT XÂY DỰNG.docx
# ============================================================
# 📂 Đường dẫn đầu vào: data/2. Tờ rơi các ngành đào tạo/ĐỊA CHẤT VÀ DẦU KHÍ/ĐỊA KỸ THUẬT XÂY DỰNG.docx
# 📁 Đường dẫn đầu ra: md_ai/2. Tờ rơi các ngành đào tạo_ĐỊA CHẤT VÀ DẦU KHÍ_ĐỊA KỸ THUẬT XÂY DỰNG.docx.md
# 📖 Đang đọc nội dung DOCX...
# 📝 Đã đọc 2170 ký tự
# 🤖 Đang chuyển đổi sang Markdown...
# 🔄 Đang gọi Together AI (lần thử 1/3)...
# ✅ Lần thử 1: Markdown hợp lệ!
# ✅ Đã lưu thành công: md_ai/2. Tờ rơi các ngành đào tạo_ĐỊA CHẤT VÀ DẦU KHÍ_ĐỊA KỸ THUẬT XÂY DỰNG.docx.md
#
# ============================================================
# 🔄 Đang xử lý file 23/42: ĐỊA CHẤT - DẦU KHÍ.docx
# ============================================================
# 📂 Đường dẫn đầu vào: data/2. Tờ rơi các ngành đào tạo/ĐỊA CHẤT VÀ DẦU KHÍ/ĐỊA CHẤT - DẦU KHÍ.docx
# 📁 Đường dẫn đầu ra: md_ai/2. Tờ rơi các ngành đào tạo_ĐỊA CHẤT VÀ DẦU KHÍ_ĐỊA CHẤT - DẦU KHÍ.docx.md
# 📖 Đang đọc nội dung DOCX...
# 📝 Đã đọc 5754 ký tự
# 🤖 Đang chuyển đổi sang Markdown...
# 🔄 Đang gọi Together AI (lần thử 1/3)...
# ✅ Lần thử 1: Markdown hợp lệ!
# ✅ Đã lưu thành công: md_ai/2. Tờ rơi các ngành đào tạo_ĐỊA CHẤT VÀ DẦU KHÍ_ĐỊA CHẤT - DẦU KHÍ.docx.md
#
# ============================================================
# 🔄 Đang xử lý file 24/42: CÔNG NGHỆ SINH HỌC.docx
# ============================================================
# 📂 Đường dẫn đầu vào: data/2. Tờ rơi các ngành đào tạo/KỸ THUẬT HÓA HỌC/CÔNG NGHỆ SINH HỌC.docx
# 📁 Đường dẫn đầu ra: md_ai/2. Tờ rơi các ngành đào tạo_KỸ THUẬT HÓA HỌC_CÔNG NGHỆ SINH HỌC.docx.md
# 📖 Đang đọc nội dung DOCX...
# 📝 Đã đọc 5885 ký tự
# 🤖 Đang chuyển đổi sang Markdown...
# 🔄 Đang gọi Together AI (lần thử 1/3)...
# ✅ Lần thử 1: Markdown hợp lệ!
# ✅ Đã lưu thành công: md_ai/2. Tờ rơi các ngành đào tạo_KỸ THUẬT HÓA HỌC_CÔNG NGHỆ SINH HỌC.docx.md
#
# ============================================================
# 🔄 Đang xử lý file 25/42: CÔNG NGHỆ THỰC PHẨM.docx
# ============================================================
# 📂 Đường dẫn đầu vào: data/2. Tờ rơi các ngành đào tạo/KỸ THUẬT HÓA HỌC/CÔNG NGHỆ THỰC PHẨM.docx
# 📁 Đường dẫn đầu ra: md_ai/2. Tờ rơi các ngành đào tạo_KỸ THUẬT HÓA HỌC_CÔNG NGHỆ THỰC PHẨM.docx.md
# 📖 Đang đọc nội dung DOCX...
# 📝 Đã đọc 5640 ký tự
# 🤖 Đang chuyển đổi sang Markdown...
# 🔄 Đang gọi Together AI (lần thử 1/3)...
# ✅ Lần thử 1: Markdown hợp lệ!
# ✅ Đã lưu thành công: md_ai/2. Tờ rơi các ngành đào tạo_KỸ THUẬT HÓA HỌC_CÔNG NGHỆ THỰC PHẨM.docx.md
#
# ============================================================
# 🔄 Đang xử lý file 26/42: KỸ THUẬT HÓA HỌC.docx
# ============================================================
# 📂 Đường dẫn đầu vào: data/2. Tờ rơi các ngành đào tạo/KỸ THUẬT HÓA HỌC/KỸ THUẬT HÓA HỌC.docx
# 📁 Đường dẫn đầu ra: md_ai/2. Tờ rơi các ngành đào tạo_KỸ THUẬT HÓA HỌC_KỸ THUẬT HÓA HỌC.docx.md
# 📖 Đang đọc nội dung DOCX...
# 📝 Đã đọc 6261 ký tự
# 🤖 Đang chuyển đổi sang Markdown...
# 🔄 Đang gọi Together AI (lần thử 1/3)...
# ✅ Lần thử 1: Markdown hợp lệ!
# ✅ Đã lưu thành công: md_ai/2. Tờ rơi các ngành đào tạo_KỸ THUẬT HÓA HỌC_KỸ THUẬT HÓA HỌC.docx.md
#
# ============================================================
# 🔄 Đang xử lý file 27/42: QUẢN LÝ TÀI NGUYÊN VÀ MÔI TRƯỜNG.docx
# ============================================================
# 📂 Đường dẫn đầu vào: data/2. Tờ rơi các ngành đào tạo/TÀI NGUYÊN VÀ MÔI TRƯỜNG/QUẢN LÝ TÀI NGUYÊN VÀ MÔI TRƯỜNG.docx
# 📁 Đường dẫn đầu ra: md_ai/2. Tờ rơi các ngành đào tạo_TÀI NGUYÊN VÀ MÔI TRƯỜNG_QUẢN LÝ TÀI NGUYÊN VÀ MÔI TRƯỜNG.docx.md
# 📖 Đang đọc nội dung DOCX...
# 📝 Đã đọc 5422 ký tự
# 🤖 Đang chuyển đổi sang Markdown...
# 🔄 Đang gọi Together AI (lần thử 1/3)...
# ✅ Lần thử 1: Markdown hợp lệ!
# ✅ Đã lưu thành công: md_ai/2. Tờ rơi các ngành đào tạo_TÀI NGUYÊN VÀ MÔI TRƯỜNG_QUẢN LÝ TÀI NGUYÊN VÀ MÔI TRƯỜNG.docx.md
#
# ============================================================
# 🔄 Đang xử lý file 28/42: KỸ THUẬT MÔI TRƯỜNG.docx
# ============================================================
# 📂 Đường dẫn đầu vào: data/2. Tờ rơi các ngành đào tạo/TÀI NGUYÊN VÀ MÔI TRƯỜNG/KỸ THUẬT MÔI TRƯỜNG.docx
# 📁 Đường dẫn đầu ra: md_ai/2. Tờ rơi các ngành đào tạo_TÀI NGUYÊN VÀ MÔI TRƯỜNG_KỸ THUẬT MÔI TRƯỜNG.docx.md
# 📖 Đang đọc nội dung DOCX...
# 📝 Đã đọc 5344 ký tự
# 🤖 Đang chuyển đổi sang Markdown...
# 🔄 Đang gọi Together AI (lần thử 1/3)...
# ✅ Lần thử 1: Markdown hợp lệ!
# ✅ Đã lưu thành công: md_ai/2. Tờ rơi các ngành đào tạo_TÀI NGUYÊN VÀ MÔI TRƯỜNG_KỸ THUẬT MÔI TRƯỜNG.docx.md
#
# ============================================================
# 🔄 Đang xử lý file 29/42: KỸ THUẬT VÀ QUẢN LÝ NƯỚC ĐÔ THỊ.docx
# ============================================================
# 📂 Đường dẫn đầu vào: data/2. Tờ rơi các ngành đào tạo/KHOA KỸ THUẬT XÂY DỰNG/KỸ THUẬT VÀ QUẢN LÝ NƯỚC ĐÔ THỊ.docx
# 📁 Đường dẫn đầu ra: md_ai/2. Tờ rơi các ngành đào tạo_KHOA KỸ THUẬT XÂY DỰNG_KỸ THUẬT VÀ QUẢN LÝ NƯỚC ĐÔ THỊ.docx.md
# 📖 Đang đọc nội dung DOCX...
# 📝 Đã đọc 5345 ký tự
# 🤖 Đang chuyển đổi sang Markdown...
# 🔄 Đang gọi Together AI (lần thử 1/3)...
# ✅ Lần thử 1: Markdown hợp lệ!
# ✅ Đã lưu thành công: md_ai/2. Tờ rơi các ngành đào tạo_KHOA KỸ THUẬT XÂY DỰNG_KỸ THUẬT VÀ QUẢN LÝ NƯỚC ĐÔ THỊ.docx.md
#
# ============================================================
# 🔄 Đang xử lý file 30/42: KỸ THUẬT XÂY DỰNG CƠ SỞ HẠ TẦNG.docx
# ============================================================
# 📂 Đường dẫn đầu vào: data/2. Tờ rơi các ngành đào tạo/KHOA KỸ THUẬT XÂY DỰNG/KỸ THUẬT XÂY DỰNG CƠ SỞ HẠ TẦNG.docx
# 📁 Đường dẫn đầu ra: md_ai/2. Tờ rơi các ngành đào tạo_KHOA KỸ THUẬT XÂY DỰNG_KỸ THUẬT XÂY DỰNG CƠ SỞ HẠ TẦNG.docx.md
# 📖 Đang đọc nội dung DOCX...
# 📝 Đã đọc 5015 ký tự
# 🤖 Đang chuyển đổi sang Markdown...
# 🔄 Đang gọi Together AI (lần thử 1/3)...
# ✅ Lần thử 1: Markdown hợp lệ!
# ✅ Đã lưu thành công: md_ai/2. Tờ rơi các ngành đào tạo_KHOA KỸ THUẬT XÂY DỰNG_KỸ THUẬT XÂY DỰNG CƠ SỞ HẠ TẦNG.docx.md
#
# ============================================================
# 🔄 Đang xử lý file 31/42: CÔNG NGHỆ KỸ THUẬT VẬT LIỆU XÂY DỰNG.docx
# ============================================================
# 📂 Đường dẫn đầu vào: data/2. Tờ rơi các ngành đào tạo/KHOA KỸ THUẬT XÂY DỰNG/CÔNG NGHỆ KỸ THUẬT VẬT LIỆU XÂY DỰNG.docx
# 📁 Đường dẫn đầu ra: md_ai/2. Tờ rơi các ngành đào tạo_KHOA KỸ THUẬT XÂY DỰNG_CÔNG NGHỆ KỸ THUẬT VẬT LIỆU XÂY DỰNG.docx.md
# 📖 Đang đọc nội dung DOCX...
# 📝 Đã đọc 5215 ký tự
# 🤖 Đang chuyển đổi sang Markdown...
# 🔄 Đang gọi Together AI (lần thử 1/3)...
# ✅ Lần thử 1: Markdown hợp lệ!
# ✅ Đã lưu thành công: md_ai/2. Tờ rơi các ngành đào tạo_KHOA KỸ THUẬT XÂY DỰNG_CÔNG NGHỆ KỸ THUẬT VẬT LIỆU XÂY DỰNG.docx.md
#
# ============================================================
# 🔄 Đang xử lý file 32/42: KIẾN TRÚC.docx
# ============================================================
# 📂 Đường dẫn đầu vào: data/2. Tờ rơi các ngành đào tạo/KHOA KỸ THUẬT XÂY DỰNG/KIẾN TRÚC.docx
# 📁 Đường dẫn đầu ra: md_ai/2. Tờ rơi các ngành đào tạo_KHOA KỸ THUẬT XÂY DỰNG_KIẾN TRÚC.docx.md
# 📖 Đang đọc nội dung DOCX...
# 📝 Đã đọc 5003 ký tự
# 🤖 Đang chuyển đổi sang Markdown...
# 🔄 Đang gọi Together AI (lần thử 1/3)...
# ✅ Lần thử 1: Markdown hợp lệ!
# ✅ Đã lưu thành công: md_ai/2. Tờ rơi các ngành đào tạo_KHOA KỸ THUẬT XÂY DỰNG_KIẾN TRÚC.docx.md
#
# ============================================================
# 🔄 Đang xử lý file 33/42: KỸ THUẬT XÂY DỰNG CÔNG TRÌNH BIỂN.docx
# ============================================================
# 📂 Đường dẫn đầu vào: data/2. Tờ rơi các ngành đào tạo/KHOA KỸ THUẬT XÂY DỰNG/KỸ THUẬT XÂY DỰNG CÔNG TRÌNH BIỂN.docx
# 📁 Đường dẫn đầu ra: md_ai/2. Tờ rơi các ngành đào tạo_KHOA KỸ THUẬT XÂY DỰNG_KỸ THUẬT XÂY DỰNG CÔNG TRÌNH BIỂN.docx.md
# 📖 Đang đọc nội dung DOCX...
# 📝 Đã đọc 5033 ký tự
# 🤖 Đang chuyển đổi sang Markdown...
# 🔄 Đang gọi Together AI (lần thử 1/3)...
# ✅ Lần thử 1: Markdown hợp lệ!
# ✅ Đã lưu thành công: md_ai/2. Tờ rơi các ngành đào tạo_KHOA KỸ THUẬT XÂY DỰNG_KỸ THUẬT XÂY DỰNG CÔNG TRÌNH BIỂN.docx.md
#
# ============================================================
# 🔄 Đang xử lý file 34/42: KỸ THUẬT XÂY DỰNG CÔNG TRÌNH GIAO THÔNG.docx
# ============================================================
# 📂 Đường dẫn đầu vào: data/2. Tờ rơi các ngành đào tạo/KHOA KỸ THUẬT XÂY DỰNG/KỸ THUẬT XÂY DỰNG CÔNG TRÌNH GIAO THÔNG.docx
# 📁 Đường dẫn đầu ra: md_ai/2. Tờ rơi các ngành đào tạo_KHOA KỸ THUẬT XÂY DỰNG_KỸ THUẬT XÂY DỰNG CÔNG TRÌNH GIAO THÔNG.docx.md
# 📖 Đang đọc nội dung DOCX...
# 📝 Đã đọc 4197 ký tự
# 🤖 Đang chuyển đổi sang Markdown...
# 🔄 Đang gọi Together AI (lần thử 1/3)...
# ✅ Lần thử 1: Markdown hợp lệ!
# ✅ Đã lưu thành công: md_ai/2. Tờ rơi các ngành đào tạo_KHOA KỸ THUẬT XÂY DỰNG_KỸ THUẬT XÂY DỰNG CÔNG TRÌNH GIAO THÔNG.docx.md
#
# ============================================================
# 🔄 Đang xử lý file 35/42: KINH TẾ XÂY DỰNG.docx
# ============================================================
# 📂 Đường dẫn đầu vào: data/2. Tờ rơi các ngành đào tạo/KHOA KỸ THUẬT XÂY DỰNG/KINH TẾ XÂY DỰNG.docx
# 📁 Đường dẫn đầu ra: md_ai/2. Tờ rơi các ngành đào tạo_KHOA KỸ THUẬT XÂY DỰNG_KINH TẾ XÂY DỰNG.docx.md
# 📖 Đang đọc nội dung DOCX...
# 📝 Đã đọc 5616 ký tự
# 🤖 Đang chuyển đổi sang Markdown...
# 🔄 Đang gọi Together AI (lần thử 1/3)...
# ✅ Lần thử 1: Markdown hợp lệ!
# ✅ Đã lưu thành công: md_ai/2. Tờ rơi các ngành đào tạo_KHOA KỸ THUẬT XÂY DỰNG_KINH TẾ XÂY DỰNG.docx.md
#
# ============================================================
# 🔄 Đang xử lý file 36/42: XÂY DỰNG DÂN DỤNG - CÔNG NGHIỆP VÀ HIỆU QUẢ NĂNG LƯỢNG.docx
# ============================================================
# 📂 Đường dẫn đầu vào: data/2. Tờ rơi các ngành đào tạo/KHOA KỸ THUẬT XÂY DỰNG/XÂY DỰNG DÂN DỤNG - CÔNG NGHIỆP VÀ HIỆU QUẢ NĂNG LƯỢNG.docx
# 📁 Đường dẫn đầu ra: md_ai/2. Tờ rơi các ngành đào tạo_KHOA KỸ THUẬT XÂY DỰNG_XÂY DỰNG DÂN DỤNG - CÔNG NGHIỆP VÀ HIỆU QUẢ NĂNG LƯỢNG.docx.md
# 📖 Đang đọc nội dung DOCX...
# 📝 Đã đọc 4258 ký tự
# 🤖 Đang chuyển đổi sang Markdown...
# 🔄 Đang gọi Together AI (lần thử 1/3)...
# ✅ Lần thử 1: Markdown hợp lệ!
# ✅ Đã lưu thành công: md_ai/2. Tờ rơi các ngành đào tạo_KHOA KỸ THUẬT XÂY DỰNG_XÂY DỰNG DÂN DỤNG - CÔNG NGHIỆP VÀ HIỆU QUẢ NĂNG LƯỢNG.docx.md
#
# ============================================================
# 🔄 Đang xử lý file 37/42: KỸ THUẬT XÂY DỰNG.docx
# ============================================================
# 📂 Đường dẫn đầu vào: data/2. Tờ rơi các ngành đào tạo/KHOA KỸ THUẬT XÂY DỰNG/KỸ THUẬT XÂY DỰNG.docx
# 📁 Đường dẫn đầu ra: md_ai/2. Tờ rơi các ngành đào tạo_KHOA KỸ THUẬT XÂY DỰNG_KỸ THUẬT XÂY DỰNG.docx.md
# 📖 Đang đọc nội dung DOCX...
# 📝 Đã đọc 3992 ký tự
# 🤖 Đang chuyển đổi sang Markdown...
# 🔄 Đang gọi Together AI (lần thử 1/3)...
# ✅ Lần thử 1: Markdown hợp lệ!
# ✅ Đã lưu thành công: md_ai/2. Tờ rơi các ngành đào tạo_KHOA KỸ THUẬT XÂY DỰNG_KỸ THUẬT XÂY DỰNG.docx.md
#
# ============================================================
# 🔄 Đang xử lý file 38/42: KHOA HỌC DỮ LIỆU.docx
# ============================================================
# 📂 Đường dẫn đầu vào: data/2. Tờ rơi các ngành đào tạo/KHOA HỌC ỨNG DỤNG/KHOA HỌC DỮ LIỆU.docx
# 📁 Đường dẫn đầu ra: md_ai/2. Tờ rơi các ngành đào tạo_KHOA HỌC ỨNG DỤNG_KHOA HỌC DỮ LIỆU.docx.md
# 📖 Đang đọc nội dung DOCX...
# 📝 Đã đọc 4936 ký tự
# 🤖 Đang chuyển đổi sang Markdown...
# 🔄 Đang gọi Together AI (lần thử 1/3)...
# ✅ Lần thử 1: Markdown hợp lệ!
# ✅ Đã lưu thành công: md_ai/2. Tờ rơi các ngành đào tạo_KHOA HỌC ỨNG DỤNG_KHOA HỌC DỮ LIỆU.docx.md
#
# ============================================================
# 🔄 Đang xử lý file 39/42: CƠ KỸ THUẬT.docx
# ============================================================
# 📂 Đường dẫn đầu vào: data/2. Tờ rơi các ngành đào tạo/KHOA HỌC ỨNG DỤNG/CƠ KỸ THUẬT.docx
# 📁 Đường dẫn đầu ra: md_ai/2. Tờ rơi các ngành đào tạo_KHOA HỌC ỨNG DỤNG_CƠ KỸ THUẬT.docx.md
# 📖 Đang đọc nội dung DOCX...
# 📝 Đã đọc 4571 ký tự
# 🤖 Đang chuyển đổi sang Markdown...
# 🔄 Đang gọi Together AI (lần thử 1/3)...
# ✅ Lần thử 1: Markdown hợp lệ!
# ✅ Đã lưu thành công: md_ai/2. Tờ rơi các ngành đào tạo_KHOA HỌC ỨNG DỤNG_CƠ KỸ THUẬT.docx.md
#
# ============================================================
# 🔄 Đang xử lý file 40/42: VẬT LÝ KỸ THUẬT.docx
# ============================================================
# 📂 Đường dẫn đầu vào: data/2. Tờ rơi các ngành đào tạo/KHOA HỌC ỨNG DỤNG/VẬT LÝ KỸ THUẬT.docx
# 📁 Đường dẫn đầu ra: md_ai/2. Tờ rơi các ngành đào tạo_KHOA HỌC ỨNG DỤNG_VẬT LÝ KỸ THUẬT.docx.md
# 📖 Đang đọc nội dung DOCX...
# 📝 Đã đọc 5595 ký tự
# 🤖 Đang chuyển đổi sang Markdown...
# 🔄 Đang gọi Together AI (lần thử 1/3)...
# ✅ Lần thử 1: Markdown hợp lệ!
# ✅ Đã lưu thành công: md_ai/2. Tờ rơi các ngành đào tạo_KHOA HỌC ỨNG DỤNG_VẬT LÝ KỸ THUẬT.docx.md
#
# ============================================================
# 🔄 Đang xử lý file 41/42: KỸ THUẬT MÁY TÍNH.docx
# ============================================================
# 📂 Đường dẫn đầu vào: data/2. Tờ rơi các ngành đào tạo/KHOA HỌC VÀ KỸ THUẬT MÁY TÍNH/KỸ THUẬT MÁY TÍNH.docx
# 📁 Đường dẫn đầu ra: md_ai/2. Tờ rơi các ngành đào tạo_KHOA HỌC VÀ KỸ THUẬT MÁY TÍNH_KỸ THUẬT MÁY TÍNH.docx.md
# 📖 Đang đọc nội dung DOCX...
# 📝 Đã đọc 7136 ký tự
# 🤖 Đang chuyển đổi sang Markdown...
# 🔄 Đang gọi Together AI (lần thử 1/3)...
# ✅ Lần thử 1: Markdown hợp lệ!
# ✅ Đã lưu thành công: md_ai/2. Tờ rơi các ngành đào tạo_KHOA HỌC VÀ KỸ THUẬT MÁY TÍNH_KỸ THUẬT MÁY TÍNH.docx.md
#
# ============================================================
# 🔄 Đang xử lý file 42/42: KHOA HỌC MÁY TÍNH.docx
# ============================================================
# 📂 Đường dẫn đầu vào: data/2. Tờ rơi các ngành đào tạo/KHOA HỌC VÀ KỸ THUẬT MÁY TÍNH/KHOA HỌC MÁY TÍNH.docx
# 📁 Đường dẫn đầu ra: md_ai/2. Tờ rơi các ngành đào tạo_KHOA HỌC VÀ KỸ THUẬT MÁY TÍNH_KHOA HỌC MÁY TÍNH.docx.md
# 📖 Đang đọc nội dung DOCX...
# 📝 Đã đọc 0 ký tự
# 🤖 Đang chuyển đổi sang Markdown...
# 🔄 Đang gọi Together AI (lần thử 1/3)...
# ⚠️  Lần thử 1: Markdown chưa hợp lệ - ['Thiếu tiêu đề chính (H1)', 'Có H3 nhưng thiếu H2']
# 🔄 Đang gọi Together AI (lần thử 2/3)...
# ⚠️  Lần thử 2: Markdown chưa hợp lệ - ['Thiếu tiêu đề chính (H1)', 'Có H3 nhưng thiếu H2']
# 🔄 Đang gọi Together AI (lần thử 3/3)...
# ⚠️  Lần thử 3: Markdown chưa hợp lệ - ['Thiếu tiêu đề chính (H1)', 'Có H3 nhưng thiếu H2']
# ⚠️  Đã thử tối đa, sử dụng kết quả cuối cùng
# ✅ Đã lưu thành công: md_ai/2. Tờ rơi các ngành đào tạo_KHOA HỌC VÀ KỸ THUẬT MÁY TÍNH_KHOA HỌC MÁY TÍNH.docx.md
#
# ============================================================
# 📊 KẾT QUẢ TỔNG KẾT:
# ✅ Thành công: 39 file
# ❌ Thất bại: 3 file
# 📁 Thư mục output: md_ai
# ============================================================
#
# 🔍 Đang kiểm tra chất lượng file Markdown...
#
# 🔍 Đang kiểm tra file Markdown trong: md_ai
#
# 📋 KẾT QUẢ KIỂM TRA:
#
# 📄 File: 2. Tờ rơi các ngành đào tạo_KHOA KỸ THUẬT XÂY DỰNG_KỸ THUẬT XÂY DỰNG CÔNG TRÌNH GIAO THÔNG.docx.md
#   ✅ Cấu trúc hợp lệ
#
# 📄 File: 2. Tờ rơi các ngành đào tạo_KHOA KỸ THUẬT XÂY DỰNG_KỸ THUẬT VÀ QUẢN LÝ NƯỚC ĐÔ THỊ.docx.md
#   ✅ Cấu trúc hợp lệ
#
# 📄 File: 2. Tờ rơi các ngành đào tạo_KỸ THUẬT HÓA HỌC_CÔNG NGHỆ SINH HỌC.docx.md
#   ✅ Cấu trúc hợp lệ
#
# 📄 File: 2. Tờ rơi các ngành đào tạo_KHOA KỸ THUẬT GIAO THÔNG_KỸ THUẬT Ô TÔ.docx.md
#   ✅ Cấu trúc hợp lệ
#
# 📄 File: 5. Thông tin PTN-xưởng_Thông tin PTN_Xưởng.docx.md
#   ✅ Cấu trúc hợp lệ
#
# 📄 File: 2. Tờ rơi các ngành đào tạo_KỸ THUẬT VẬT LIỆU.docx.md
#   ✅ Cấu trúc hợp lệ
#
# 📄 File: 2. Tờ rơi các ngành đào tạo_CƠ KHÍ_LOGISTIC VÀ HỆ THỐNG CÔNG NGHIỆP.docx.md
#   ✅ Cấu trúc hợp lệ
#
# 📄 File: 2. Tờ rơi các ngành đào tạo_Mẫu Thông tin về ngành Kinh doanh số.docx.md
#   ✅ Cấu trúc hợp lệ
#
# 📄 File: 2. Tờ rơi các ngành đào tạo_KỸ THUẬT HÓA HỌC_CÔNG NGHỆ THỰC PHẨM.docx.md
#   ✅ Cấu trúc hợp lệ
#
# 📄 File: 2. Tờ rơi các ngành đào tạo_KHOA KỸ THUẬT XÂY DỰNG_KỸ THUẬT XÂY DỰNG CƠ SỞ HẠ TẦNG.docx.md
#   ✅ Cấu trúc hợp lệ
#
# 📄 File: 2. Tờ rơi các ngành đào tạo_QUẢN LÝ CÔNG NGHIỆP.docx.md
#   ✅ Cấu trúc hợp lệ
#
# 📄 File: 2. Tờ rơi các ngành đào tạo_KHOA HỌC ỨNG DỤNG_VẬT LÝ KỸ THUẬT.docx.md
#   ✅ Cấu trúc hợp lệ
#
# 📄 File: 2. Tờ rơi các ngành đào tạo_ĐIỆN - ĐIỆN TỬ_THIẾT KẾ VI MẠCH.docx.md
#   ✅ Cấu trúc hợp lệ
#
# 📄 File: 2. Tờ rơi các ngành đào tạo_ĐIỆN - ĐIỆN TỬ_ĐIỆN TỬ - VIỄN THÔNG.docx.md
#   ✅ Cấu trúc hợp lệ
#
# 📄 File: 2. Tờ rơi các ngành đào tạo_KHOA HỌC VÀ KỸ THUẬT MÁY TÍNH_KỸ THUẬT MÁY TÍNH.docx.md
#   ✅ Cấu trúc hợp lệ
#
# 📄 File: 2. Tờ rơi các ngành đào tạo_CƠ KHÍ_BẢO DƯỠNG CÔNG NGHIỆP.docx.md
#   ✅ Cấu trúc hợp lệ
#
# 📄 File: 2. Tờ rơi các ngành đào tạo_KHOA HỌC ỨNG DỤNG_KHOA HỌC DỮ LIỆU.docx.md
#   ✅ Cấu trúc hợp lệ
#
# 📄 File: 2. Tờ rơi các ngành đào tạo_KHOA HỌC ỨNG DỤNG_CƠ KỸ THUẬT.docx.md
#   ✅ Cấu trúc hợp lệ
#
# 📄 File: 2. Tờ rơi các ngành đào tạo_KHOA KỸ THUẬT XÂY DỰNG_KINH TẾ XÂY DỰNG.docx.md
#   ✅ Cấu trúc hợp lệ
#
# 📄 File: 2. Tờ rơi các ngành đào tạo_CƠ KHÍ_KỸ THUẬT CƠ KHÍ.docx.md
#   ✅ Cấu trúc hợp lệ
#
# 📄 File: 2. Tờ rơi các ngành đào tạo_KHOA KỸ THUẬT GIAO THÔNG_KỸ THUẬT TÀU THỦY.docx.md
#   ✅ Cấu trúc hợp lệ
#
# 📄 File: 2. Tờ rơi các ngành đào tạo_CƠ KHÍ_KỸ THUẬT CƠ ĐIỆN TỬ.docx.md
#   ✅ Cấu trúc hợp lệ
#
# 📄 File: 2. Tờ rơi các ngành đào tạo_TÀI NGUYÊN VÀ MÔI TRƯỜNG_QUẢN LÝ TÀI NGUYÊN VÀ MÔI TRƯỜNG.docx.md
#   ✅ Cấu trúc hợp lệ
#
# 📄 File: 2. Tờ rơi các ngành đào tạo_CƠ KHÍ_KỸ THUẬT NHIỆT.docx.md
#   ✅ Cấu trúc hợp lệ
#
# 📄 File: 2. Tờ rơi các ngành đào tạo_KHOA KỸ THUẬT GIAO THÔNG_KỸ THUẬT HÀNG KHÔNG.docx.md
#   ✅ Cấu trúc hợp lệ
#
# 📄 File: 2. Tờ rơi các ngành đào tạo_KHOA KỸ THUẬT XÂY DỰNG_CÔNG NGHỆ KỸ THUẬT VẬT LIỆU XÂY DỰNG.docx.md
#   ✅ Cấu trúc hợp lệ
#
# 📄 File: 2. Tờ rơi các ngành đào tạo_TÀI NGUYÊN VÀ MÔI TRƯỜNG_KỸ THUẬT MÔI TRƯỜNG.docx.md
#   ✅ Cấu trúc hợp lệ
#
# 📄 File: 2. Tờ rơi các ngành đào tạo_CƠ KHÍ_KỸ THUẬT DỆT, CÔNG NGHỆ DỆT, MAY.docx.md
#   ✅ Cấu trúc hợp lệ
#
# 📄 File: 2. Tờ rơi các ngành đào tạo_ĐIỆN - ĐIỆN TỬ_ĐIỀU KHIỂN VÀ TỰ ĐỘNG HÓA.docx.md
#   ✅ Cấu trúc hợp lệ
#
# 📄 File: 2. Tờ rơi các ngành đào tạo_ĐIỆN - ĐIỆN TỬ_KỸ THUẬT ĐIỆN.docx.md
#   ✅ Cấu trúc hợp lệ
#
# 📄 File: 2. Tờ rơi các ngành đào tạo_KHOA KỸ THUẬT XÂY DỰNG_XÂY DỰNG DÂN DỤNG - CÔNG NGHIỆP VÀ HIỆU QUẢ NĂNG LƯỢNG.docx.md
#   ✅ Cấu trúc hợp lệ
#
# 📄 File: 2. Tờ rơi các ngành đào tạo_ĐỊA CHẤT VÀ DẦU KHÍ_ĐỊA CHẤT - DẦU KHÍ.docx.md
#   ✅ Cấu trúc hợp lệ
#
# 📄 File: 2. Tờ rơi các ngành đào tạo_ĐỊA CHẤT VÀ DẦU KHÍ_ĐỊA KỸ THUẬT XÂY DỰNG.docx.md
#   ✅ Cấu trúc hợp lệ
#
# 📄 File: 2. Tờ rơi các ngành đào tạo_KHOA KỸ THUẬT XÂY DỰNG_KIẾN TRÚC.docx.md
#   ✅ Cấu trúc hợp lệ
#
# 📄 File: 2. Tờ rơi các ngành đào tạo_KỸ THUẬT HÓA HỌC_KỸ THUẬT HÓA HỌC.docx.md
#   ✅ Cấu trúc hợp lệ
#
# 📄 File: 2. Tờ rơi các ngành đào tạo_KHOA HỌC VÀ KỸ THUẬT MÁY TÍNH_KHOA HỌC MÁY TÍNH.docx.md
#   ⚠️  Thiếu tiêu đề chính (H1)
#   ⚠️  Có H3 nhưng thiếu H2
#
# 📄 File: 2. Tờ rơi các ngành đào tạo_KHOA KỸ THUẬT XÂY DỰNG_KỸ THUẬT XÂY DỰNG CÔNG TRÌNH BIỂN.docx.md
#   ✅ Cấu trúc hợp lệ
#
# 📄 File: 2. Tờ rơi các ngành đào tạo_PFIEV.docx.md
#   ✅ Cấu trúc hợp lệ
#
# 📄 File: 2. Tờ rơi các ngành đào tạo_KHOA KỸ THUẬT XÂY DỰNG_KỸ THUẬT XÂY DỰNG.docx.md
#   ✅ Cấu trúc hợp lệ

# %%
#check markdown
import os
import re

def validate_markdown_structure(content):
    errors = []
    
    # Kiểm tra tiêu đề chính
    if not re.search(r'^#\s+.+', content, re.MULTILINE):
        errors.append("Thiếu tiêu đề chính (H1)")
    
    # Kiểm tra tỷ lệ heading hợp lý
    h2_count = len(re.findall(r'^##\s+', content, re.MULTILINE))
    h3_count = len(re.findall(r'^###\s+', content, re.MULTILINE))
    
    if h3_count > 0 and h2_count == 0:
        errors.append("Có H3 nhưng thiếu H2")
    
    # Kiểm tra code block đóng mở đúng
    code_blocks = re.findall(r'```', content)
    if len(code_blocks) % 2 != 0:
        errors.append("Code block chưa đóng")
    
    return errors if errors else "Cấu trúc hợp lệ"


def check_markdown_files_in_folder(folder_path):
    result = {}
    
    # Duyệt qua tất cả file trong thư mục
    for filename in os.listdir(folder_path):
        if filename.endswith('.md'):  # Kiểm tra nếu file có đuôi .md
            file_path = os.path.join(folder_path, filename)
            try:
                with open(file_path, 'r', encoding='utf-8') as file:
                    content = file.read()
                    validation_result = validate_markdown_structure(content)
                    result[filename] = validation_result
            except Exception as e:
                result[filename] = f"Lỗi khi đọc file: {e}"
    
    return result


# Ví dụ sử dụng
folder_path = './md_ai'  # Đổi thành đường dẫn thực tế
validation_results = check_markdown_files_in_folder(folder_path)

for filename, result in validation_results.items():
    print(f"File: {filename}")
    if isinstance(result, list):
        for error in result:
            print(f"  - {error}")
    else:
        print(f"  - {result}")
# Out:
# File: 2. Tờ rơi các ngành đào tạo_KHOA KỸ THUẬT XÂY DỰNG_KỸ THUẬT XÂY DỰNG CÔNG TRÌNH GIAO THÔNG.docx.md
#   - Cấu trúc hợp lệ
# File: 2. Tờ rơi các ngành đào tạo_KHOA KỸ THUẬT XÂY DỰNG_KỸ THUẬT VÀ QUẢN LÝ NƯỚC ĐÔ THỊ.docx.md
#   - Cấu trúc hợp lệ
# File: 2. Tờ rơi các ngành đào tạo_KỸ THUẬT HÓA HỌC_CÔNG NGHỆ SINH HỌC.docx.md
#   - Cấu trúc hợp lệ
# File: 2. Tờ rơi các ngành đào tạo_KHOA KỸ THUẬT GIAO THÔNG_KỸ THUẬT Ô TÔ.docx.md
#   - Cấu trúc hợp lệ
# File: 5. Thông tin PTN-xưởng_Thông tin PTN_Xưởng.docx.md
#   - Cấu trúc hợp lệ
# File: 2. Tờ rơi các ngành đào tạo_KỸ THUẬT VẬT LIỆU.docx.md
#   - Cấu trúc hợp lệ
# File: 2. Tờ rơi các ngành đào tạo_CƠ KHÍ_LOGISTIC VÀ HỆ THỐNG CÔNG NGHIỆP.docx.md
#   - Cấu trúc hợp lệ
# File: 2. Tờ rơi các ngành đào tạo_Mẫu Thông tin về ngành Kinh doanh số.docx.md
#   - Cấu trúc hợp lệ
# File: 2. Tờ rơi các ngành đào tạo_KỸ THUẬT HÓA HỌC_CÔNG NGHỆ THỰC PHẨM.docx.md
#   - Cấu trúc hợp lệ
# File: 2. Tờ rơi các ngành đào tạo_KHOA KỸ THUẬT XÂY DỰNG_KỸ THUẬT XÂY DỰNG CƠ SỞ HẠ TẦNG.docx.md
#   - Cấu trúc hợp lệ
# File: 2. Tờ rơi các ngành đào tạo_QUẢN LÝ CÔNG NGHIỆP.docx.md
#   - Cấu trúc hợp lệ
# File: 2. Tờ rơi các ngành đào tạo_KHOA HỌC ỨNG DỤNG_VẬT LÝ KỸ THUẬT.docx.md
#   - Cấu trúc hợp lệ
# File: 2. Tờ rơi các ngành đào tạo_ĐIỆN - ĐIỆN TỬ_THIẾT KẾ VI MẠCH.docx.md
#   - Cấu trúc hợp lệ
# File: 2. Tờ rơi các ngành đào tạo_ĐIỆN - ĐIỆN TỬ_ĐIỆN TỬ - VIỄN THÔNG.docx.md
#   - Cấu trúc hợp lệ
# File: 2. Tờ rơi các ngành đào tạo_KHOA HỌC VÀ KỸ THUẬT MÁY TÍNH_KỸ THUẬT MÁY TÍNH.docx.md
#   - Cấu trúc hợp lệ
# File: 2. Tờ rơi các ngành đào tạo_CƠ KHÍ_BẢO DƯỠNG CÔNG NGHIỆP.docx.md
#   - Cấu trúc hợp lệ
# File: 4. Thông tin các khoa.md
#   - Cấu trúc hợp lệ
# File: 2. Tờ rơi các ngành đào tạo_KHOA HỌC ỨNG DỤNG_KHOA HỌC DỮ LIỆU.docx.md
#   - Cấu trúc hợp lệ
# File: 2. Tờ rơi các ngành đào tạo_KHOA HỌC ỨNG DỤNG_CƠ KỸ THUẬT.docx.md
#   - Cấu trúc hợp lệ
# File: 2. Tờ rơi các ngành đào tạo_KHOA KỸ THUẬT XÂY DỰNG_KINH TẾ XÂY DỰNG.docx.md
#   - Cấu trúc hợp lệ
# File: 2. Tờ rơi các ngành đào tạo_CƠ KHÍ_KỸ THUẬT CƠ KHÍ.docx.md
#   - Cấu trúc hợp lệ
# File: 2. Tờ rơi các ngành đào tạo_KHOA KỸ THUẬT GIAO THÔNG_KỸ THUẬT TÀU THỦY.docx.md
#   - Cấu trúc hợp lệ
# File: 2. Tờ rơi các ngành đào tạo_CƠ KHÍ_KỸ THUẬT CƠ ĐIỆN TỬ.docx.md
#   - Cấu trúc hợp lệ
# File: 2. Tờ rơi các ngành đào tạo_TÀI NGUYÊN VÀ MÔI TRƯỜNG_QUẢN LÝ TÀI NGUYÊN VÀ MÔI TRƯỜNG.docx.md
#   - Cấu trúc hợp lệ
# File: 3. Thông tin lãnh đạo.md
#   - Cấu trúc hợp lệ
# File: 2. Tờ rơi các ngành đào tạo_CƠ KHÍ_KỸ THUẬT NHIỆT.docx.md
#   - Cấu trúc hợp lệ
# File: 2. Tờ rơi các ngành đào tạo_KHOA KỸ THUẬT GIAO THÔNG_KỸ THUẬT HÀNG KHÔNG.docx.md
#   - Cấu trúc hợp lệ
# File: 1. Thông tin tuyển sinh .md
#   - Cấu trúc hợp lệ
# File: 2. Tờ rơi các ngành đào tạo_KHOA KỸ THUẬT XÂY DỰNG_CÔNG NGHỆ KỸ THUẬT VẬT LIỆU XÂY DỰNG.docx.md
#   - Cấu trúc hợp lệ
# File: 2. Tờ rơi các ngành đào tạo_TÀI NGUYÊN VÀ MÔI TRƯỜNG_KỸ THUẬT MÔI TRƯỜNG.docx.md
#   - Cấu trúc hợp lệ
# File: 2. Tờ rơi các ngành đào tạo_CƠ KHÍ_KỸ THUẬT DỆT, CÔNG NGHỆ DỆT, MAY.docx.md
#   - Cấu trúc hợp lệ
# File: 2. Tờ rơi các ngành đào tạo_ĐIỆN - ĐIỆN TỬ_ĐIỀU KHIỂN VÀ TỰ ĐỘNG HÓA.docx.md
#   - Cấu trúc hợp lệ
# File: 2. Tờ rơi các ngành đào tạo_ĐIỆN - ĐIỆN TỬ_KỸ THUẬT ĐIỆN.docx.md
#   - Cấu trúc hợp lệ
# File: 2. Tờ rơi các ngành đào tạo_KHOA KỸ THUẬT XÂY DỰNG_XÂY DỰNG DÂN DỤNG - CÔNG NGHIỆP VÀ HIỆU QUẢ NĂNG LƯỢNG.docx.md
#   - Cấu trúc hợp lệ
# File: 2. Tờ rơi các ngành đào tạo_ĐỊA CHẤT VÀ DẦU KHÍ_ĐỊA CHẤT - DẦU KHÍ.docx.md
#   - Cấu trúc hợp lệ
# File: 2. Tờ rơi các ngành đào tạo_ĐỊA CHẤT VÀ DẦU KHÍ_ĐỊA KỸ THUẬT XÂY DỰNG.docx.md
#   - Cấu trúc hợp lệ
# File: 2. Tờ rơi các ngành đào tạo_KHOA KỸ THUẬT XÂY DỰNG_KIẾN TRÚC.docx.md
#   - Cấu trúc hợp lệ
# File: 2. Tờ rơi các ngành đào tạo_KỸ THUẬT HÓA HỌC_KỸ THUẬT HÓA HỌC.docx.md
#   - Cấu trúc hợp lệ
# File: 2. Tờ rơi các ngành đào tạo_KHOA HỌC VÀ KỸ THUẬT MÁY TÍNH_KHOA HỌC MÁY TÍNH.docx.md
#   - Thiếu tiêu đề chính (H1)
#   - Có H3 nhưng thiếu H2
# File: 2. Tờ rơi các ngành đào tạo_KHOA KỸ THUẬT XÂY DỰNG_KỸ THUẬT XÂY DỰNG CÔNG TRÌNH BIỂN.docx.md
#   - Cấu trúc hợp lệ
# File: 2. Tờ rơi các ngành đào tạo_PFIEV.docx.md
#   - Cấu trúc hợp lệ
# File: 2. Tờ rơi các ngành đào tạo_KHOA KỸ THUẬT XÂY DỰNG_KỸ THUẬT XÂY DỰNG.docx.md
#   - Cấu trúc hợp lệ

# %%
import os
from langchain.text_splitter import MarkdownHeaderTextSplitter

# Đường dẫn thư mục đầu vào và đầu ra
input_folder = "./md_ai"  # Thư mục chứa các tệp markdown đã chuyển đổi
output_folder = "./chunked"

# Kiểm tra và tạo thư mục đầu ra nếu chưa có
os.makedirs(output_folder, exist_ok=True)

# Danh sách các tệp markdown trong thư mục đầu vào
input_files = [f for f in os.listdir(input_folder) if f.endswith('.md')]

headers_to_split_on = [
    ("#", "Header 1"),
    ("##", "Header 2"),
    ("###", "Header 3"),
]

# Chunking dựa trên cấu trúc markdown
splitter = MarkdownHeaderTextSplitter(
    headers_to_split_on=headers_to_split_on,
    strip_headers=False  # Giữ nguyên tiêu đề trong nội dung
)

# Lặp qua các tệp markdown
for input_file in input_files:
    input_path = os.path.join(input_folder, input_file)
    
    # Đọc nội dung của tệp markdown
    with open(input_path, 'r', encoding='utf-8') as f:
        markdown_content = f.read()

    # Tiến hành chia chunk
    structural_chunks = splitter.split_text(markdown_content)

    # Lưu metadata cấu trúc
    metadata_list = []
    for chunk in structural_chunks:
        metadata = {
            'header': chunk.metadata.get('Header 2', ''),
            'subheader': chunk.metadata.get('Header 3', ''),
            'content_with_markdown': chunk.page_content  # Giữ nguyên markdown
        }
        metadata_list.append(metadata)

    # Tạo tệp output
    output_file = os.path.join(output_folder, f"{os.path.splitext(input_file)[0]}_output.json")
    
    # Lưu metadata dưới dạng tệp JSON (hoặc định dạng bạn muốn)
    with open(output_file, 'w', encoding='utf-8') as out_f:
        import json
        json.dump(metadata_list, out_f, ensure_ascii=False, indent=4)

    print(f"Đã xử lý và lưu tệp {input_file} vào {output_file}")
# Out:
# Đã xử lý và lưu tệp 2. Tờ rơi các ngành đào tạo_KHOA KỸ THUẬT XÂY DỰNG_KỸ THUẬT XÂY DỰNG CÔNG TRÌNH GIAO THÔNG.docx.md vào ./chunked/2. Tờ rơi các ngành đào tạo_KHOA KỸ THUẬT XÂY DỰNG_KỸ THUẬT XÂY DỰNG CÔNG TRÌNH GIAO THÔNG.docx_output.json
# Đã xử lý và lưu tệp 2. Tờ rơi các ngành đào tạo_KHOA KỸ THUẬT XÂY DỰNG_KỸ THUẬT VÀ QUẢN LÝ NƯỚC ĐÔ THỊ.docx.md vào ./chunked/2. Tờ rơi các ngành đào tạo_KHOA KỸ THUẬT XÂY DỰNG_KỸ THUẬT VÀ QUẢN LÝ NƯỚC ĐÔ THỊ.docx_output.json
# Đã xử lý và lưu tệp 2. Tờ rơi các ngành đào tạo_KỸ THUẬT HÓA HỌC_CÔNG NGHỆ SINH HỌC.docx.md vào ./chunked/2. Tờ rơi các ngành đào tạo_KỸ THUẬT HÓA HỌC_CÔNG NGHỆ SINH HỌC.docx_output.json
# Đã xử lý và lưu tệp 2. Tờ rơi các ngành đào tạo_KHOA KỸ THUẬT GIAO THÔNG_KỸ THUẬT Ô TÔ.docx.md vào ./chunked/2. Tờ rơi các ngành đào tạo_KHOA KỸ THUẬT GIAO THÔNG_KỸ THUẬT Ô TÔ.docx_output.json
# Đã xử lý và lưu tệp 5. Thông tin PTN-xưởng_Thông tin PTN_Xưởng.docx.md vào ./chunked/5. Thông tin PTN-xưởng_Thông tin PTN_Xưởng.docx_output.json
# Đã xử lý và lưu tệp 2. Tờ rơi các ngành đào tạo_KỸ THUẬT VẬT LIỆU.docx.md vào ./chunked/2. Tờ rơi các ngành đào tạo_KỸ THUẬT VẬT LIỆU.docx_output.json
# Đã xử lý và lưu tệp 2. Tờ rơi các ngành đào tạo_CƠ KHÍ_LOGISTIC VÀ HỆ THỐNG CÔNG NGHIỆP.docx.md vào ./chunked/2. Tờ rơi các ngành đào tạo_CƠ KHÍ_LOGISTIC VÀ HỆ THỐNG CÔNG NGHIỆP.docx_output.json
# Đã xử lý và lưu tệp 2. Tờ rơi các ngành đào tạo_Mẫu Thông tin về ngành Kinh doanh số.docx.md vào ./chunked/2. Tờ rơi các ngành đào tạo_Mẫu Thông tin về ngành Kinh doanh số.docx_output.json
# Đã xử lý và lưu tệp 2. Tờ rơi các ngành đào tạo_KỸ THUẬT HÓA HỌC_CÔNG NGHỆ THỰC PHẨM.docx.md vào ./chunked/2. Tờ rơi các ngành đào tạo_KỸ THUẬT HÓA HỌC_CÔNG NGHỆ THỰC PHẨM.docx_output.json
# Đã xử lý và lưu tệp 2. Tờ rơi các ngành đào tạo_KHOA KỸ THUẬT XÂY DỰNG_KỸ THUẬT XÂY DỰNG CƠ SỞ HẠ TẦNG.docx.md vào ./chunked/2. Tờ rơi các ngành đào tạo_KHOA KỸ THUẬT XÂY DỰNG_KỸ THUẬT XÂY DỰNG CƠ SỞ HẠ TẦNG.docx_output.json
# Đã xử lý và lưu tệp 2. Tờ rơi các ngành đào tạo_QUẢN LÝ CÔNG NGHIỆP.docx.md vào ./chunked/2. Tờ rơi các ngành đào tạo_QUẢN LÝ CÔNG NGHIỆP.docx_output.json
# Đã xử lý và lưu tệp 2. Tờ rơi các ngành đào tạo_KHOA HỌC ỨNG DỤNG_VẬT LÝ KỸ THUẬT.docx.md vào ./chunked/2. Tờ rơi các ngành đào tạo_KHOA HỌC ỨNG DỤNG_VẬT LÝ KỸ THUẬT.docx_output.json
# Đã xử lý và lưu tệp 2. Tờ rơi các ngành đào tạo_ĐIỆN - ĐIỆN TỬ_THIẾT KẾ VI MẠCH.docx.md vào ./chunked/2. Tờ rơi các ngành đào tạo_ĐIỆN - ĐIỆN TỬ_THIẾT KẾ VI MẠCH.docx_output.json
# Đã xử lý và lưu tệp 2. Tờ rơi các ngành đào tạo_ĐIỆN - ĐIỆN TỬ_ĐIỆN TỬ - VIỄN THÔNG.docx.md vào ./chunked/2. Tờ rơi các ngành đào tạo_ĐIỆN - ĐIỆN TỬ_ĐIỆN TỬ - VIỄN THÔNG.docx_output.json
# Đã xử lý và lưu tệp 2. Tờ rơi các ngành đào tạo_KHOA HỌC VÀ KỸ THUẬT MÁY TÍNH_KỸ THUẬT MÁY TÍNH.docx.md vào ./chunked/2. Tờ rơi các ngành đào tạo_KHOA HỌC VÀ KỸ THUẬT MÁY TÍNH_KỸ THUẬT MÁY TÍNH.docx_output.json
# Đã xử lý và lưu tệp 2. Tờ rơi các ngành đào tạo_CƠ KHÍ_BẢO DƯỠNG CÔNG NGHIỆP.docx.md vào ./chunked/2. Tờ rơi các ngành đào tạo_CƠ KHÍ_BẢO DƯỠNG CÔNG NGHIỆP.docx_output.json
# Đã xử lý và lưu tệp 4. Thông tin các khoa.md vào ./chunked/4. Thông tin các khoa_output.json
# Đã xử lý và lưu tệp 2. Tờ rơi các ngành đào tạo_KHOA HỌC ỨNG DỤNG_KHOA HỌC DỮ LIỆU.docx.md vào ./chunked/2. Tờ rơi các ngành đào tạo_KHOA HỌC ỨNG DỤNG_KHOA HỌC DỮ LIỆU.docx_output.json
# Đã xử lý và lưu tệp 2. Tờ rơi các ngành đào tạo_KHOA HỌC ỨNG DỤNG_CƠ KỸ THUẬT.docx.md vào ./chunked/2. Tờ rơi các ngành đào tạo_KHOA HỌC ỨNG DỤNG_CƠ KỸ THUẬT.docx_output.json
# Đã xử lý và lưu tệp 2. Tờ rơi các ngành đào tạo_KHOA KỸ THUẬT XÂY DỰNG_KINH TẾ XÂY DỰNG.docx.md vào ./chunked/2. Tờ rơi các ngành đào tạo_KHOA KỸ THUẬT XÂY DỰNG_KINH TẾ XÂY DỰNG.docx_output.json
# Đã xử lý và lưu tệp 2. Tờ rơi các ngành đào tạo_CƠ KHÍ_KỸ THUẬT CƠ KHÍ.docx.md vào ./chunked/2. Tờ rơi các ngành đào tạo_CƠ KHÍ_KỸ THUẬT CƠ KHÍ.docx_output.json
# Đã xử lý và lưu tệp 2. Tờ rơi các ngành đào tạo_KHOA KỸ THUẬT GIAO THÔNG_KỸ THUẬT TÀU THỦY.docx.md vào ./chunked/2. Tờ rơi các ngành đào tạo_KHOA KỸ THUẬT GIAO THÔNG_KỸ THUẬT TÀU THỦY.docx_output.json
# Đã xử lý và lưu tệp 2. Tờ rơi các ngành đào tạo_CƠ KHÍ_KỸ THUẬT CƠ ĐIỆN TỬ.docx.md vào ./chunked/2. Tờ rơi các ngành đào tạo_CƠ KHÍ_KỸ THUẬT CƠ ĐIỆN TỬ.docx_output.json
# Đã xử lý và lưu tệp 2. Tờ rơi các ngành đào tạo_TÀI NGUYÊN VÀ MÔI TRƯỜNG_QUẢN LÝ TÀI NGUYÊN VÀ MÔI TRƯỜNG.docx.md vào ./chunked/2. Tờ rơi các ngành đào tạo_TÀI NGUYÊN VÀ MÔI TRƯỜNG_QUẢN LÝ TÀI NGUYÊN VÀ MÔI TRƯỜNG.docx_output.json
# Đã xử lý và lưu tệp 3. Thông tin lãnh đạo.md vào ./chunked/3. Thông tin lãnh đạo_output.json
# Đã xử lý và lưu tệp 2. Tờ rơi các ngành đào tạo_CƠ KHÍ_KỸ THUẬT NHIỆT.docx.md vào ./chunked/2. Tờ rơi các ngành đào tạo_CƠ KHÍ_KỸ THUẬT NHIỆT.docx_output.json
# Đã xử lý và lưu tệp 2. Tờ rơi các ngành đào tạo_KHOA KỸ THUẬT GIAO THÔNG_KỸ THUẬT HÀNG KHÔNG.docx.md vào ./chunked/2. Tờ rơi các ngành đào tạo_KHOA KỸ THUẬT GIAO THÔNG_KỸ THUẬT HÀNG KHÔNG.docx_output.json
# Đã xử lý và lưu tệp 1. Thông tin tuyển sinh .md vào ./chunked/1. Thông tin tuyển sinh _output.json
# Đã xử lý và lưu tệp 2. Tờ rơi các ngành đào tạo_KHOA KỸ THUẬT XÂY DỰNG_CÔNG NGHỆ KỸ THUẬT VẬT LIỆU XÂY DỰNG.docx.md vào ./chunked/2. Tờ rơi các ngành đào tạo_KHOA KỸ THUẬT XÂY DỰNG_CÔNG NGHỆ KỸ THUẬT VẬT LIỆU XÂY DỰNG.docx_output.json
# Đã xử lý và lưu tệp 2. Tờ rơi các ngành đào tạo_TÀI NGUYÊN VÀ MÔI TRƯỜNG_KỸ THUẬT MÔI TRƯỜNG.docx.md vào ./chunked/2. Tờ rơi các ngành đào tạo_TÀI NGUYÊN VÀ MÔI TRƯỜNG_KỸ THUẬT MÔI TRƯỜNG.docx_output.json
# Đã xử lý và lưu tệp 2. Tờ rơi các ngành đào tạo_CƠ KHÍ_KỸ THUẬT DỆT, CÔNG NGHỆ DỆT, MAY.docx.md vào ./chunked/2. Tờ rơi các ngành đào tạo_CƠ KHÍ_KỸ THUẬT DỆT, CÔNG NGHỆ DỆT, MAY.docx_output.json
# Đã xử lý và lưu tệp 2. Tờ rơi các ngành đào tạo_ĐIỆN - ĐIỆN TỬ_ĐIỀU KHIỂN VÀ TỰ ĐỘNG HÓA.docx.md vào ./chunked/2. Tờ rơi các ngành đào tạo_ĐIỆN - ĐIỆN TỬ_ĐIỀU KHIỂN VÀ TỰ ĐỘNG HÓA.docx_output.json
# Đã xử lý và lưu tệp 2. Tờ rơi các ngành đào tạo_ĐIỆN - ĐIỆN TỬ_KỸ THUẬT ĐIỆN.docx.md vào ./chunked/2. Tờ rơi các ngành đào tạo_ĐIỆN - ĐIỆN TỬ_KỸ THUẬT ĐIỆN.docx_output.json
# Đã xử lý và lưu tệp 2. Tờ rơi các ngành đào tạo_KHOA KỸ THUẬT XÂY DỰNG_XÂY DỰNG DÂN DỤNG - CÔNG NGHIỆP VÀ HIỆU QUẢ NĂNG LƯỢNG.docx.md vào ./chunked/2. Tờ rơi các ngành đào tạo_KHOA KỸ THUẬT XÂY DỰNG_XÂY DỰNG DÂN DỤNG - CÔNG NGHIỆP VÀ HIỆU QUẢ NĂNG LƯỢNG.docx_output.json
# Đã xử lý và lưu tệp 2. Tờ rơi các ngành đào tạo_ĐỊA CHẤT VÀ DẦU KHÍ_ĐỊA CHẤT - DẦU KHÍ.docx.md vào ./chunked/2. Tờ rơi các ngành đào tạo_ĐỊA CHẤT VÀ DẦU KHÍ_ĐỊA CHẤT - DẦU KHÍ.docx_output.json
# Đã xử lý và lưu tệp 2. Tờ rơi các ngành đào tạo_ĐỊA CHẤT VÀ DẦU KHÍ_ĐỊA KỸ THUẬT XÂY DỰNG.docx.md vào ./chunked/2. Tờ rơi các ngành đào tạo_ĐỊA CHẤT VÀ DẦU KHÍ_ĐỊA KỸ THUẬT XÂY DỰNG.docx_output.json
# Đã xử lý và lưu tệp 2. Tờ rơi các ngành đào tạo_KHOA KỸ THUẬT XÂY DỰNG_KIẾN TRÚC.docx.md vào ./chunked/2. Tờ rơi các ngành đào tạo_KHOA KỸ THUẬT XÂY DỰNG_KIẾN TRÚC.docx_output.json
# Đã xử lý và lưu tệp 2. Tờ rơi các ngành đào tạo_KỸ THUẬT HÓA HỌC_KỸ THUẬT HÓA HỌC.docx.md vào ./chunked/2. Tờ rơi các ngành đào tạo_KỸ THUẬT HÓA HỌC_KỸ THUẬT HÓA HỌC.docx_output.json
# Đã xử lý và lưu tệp 2. Tờ rơi các ngành đào tạo_KHOA KỸ THUẬT XÂY DỰNG_KỸ THUẬT XÂY DỰNG CÔNG TRÌNH BIỂN.docx.md vào ./chunked/2. Tờ rơi các ngành đào tạo_KHOA KỸ THUẬT XÂY DỰNG_KỸ THUẬT XÂY DỰNG CÔNG TRÌNH BIỂN.docx_output.json
# Đã xử lý và lưu tệp 2. Tờ rơi các ngành đào tạo_PFIEV.docx.md vào ./chunked/2. Tờ rơi các ngành đào tạo_PFIEV.docx_output.json
# Đã xử lý và lưu tệp 2. Tờ rơi các ngành đào tạo_KHOA KỸ THUẬT XÂY DỰNG_KỸ THUẬT XÂY DỰNG.docx.md vào ./chunked/2. Tờ rơi các ngành đào tạo_KHOA KỸ THUẬT XÂY DỰNG_KỸ THUẬT XÂY DỰNG.docx_output.json

# %%
import os
import pandas as pd
from pathlib import Path

def convert_xlsx_to_csv(source_folder, dest_folder):
    # Tạo thư mục đích nếu chưa tồn tại
    Path(dest_folder).mkdir(parents=True, exist_ok=True)
    
    # Duyệt qua tất cả file trong thư mục nguồn
    for file_name in os.listdir(source_folder):
        if file_name.endswith(('.xlsx', '.xls')):
            file_path = os.path.join(source_folder, file_name)
            
            try:
                # Đọc file Excel
                df = pd.read_excel(file_path, header=0)
                
                # Đổi tên cột (nếu có ít nhất 3 cột)
                new_columns = ['question', 'answer', 'keyword'] + [f'extra_{i}' for i in range(len(df.columns)-3)]
                df.columns = new_columns[:len(df.columns)]
                
                # Tạo tên file CSV
                csv_name = os.path.splitext(file_name)[0] + '.csv'
                csv_path = os.path.join(dest_folder, csv_name)
                
                # Lưu file CSV
                df.to_csv(csv_path, index=False)
                print(f"Đã chuyển đổi: {file_name} -> {csv_name}")
                
            except Exception as e:
                print(f"Lỗi khi xử lý {file_name}: {str(e)}")

if __name__ == "__main__":
    source ='./Phần việc của Hoàng Bùi Nghĩa Dũng'
    dest = './FAQs'
    
    convert_xlsx_to_csv(source, dest)
    print("Hoàn tất quá trình chuyển đổi!")
# Out:
# Đã chuyển đổi: Điện tử - Viễn thông.xlsx -> Điện tử - Viễn thông.csv
# Đã chuyển đổi: Kỹ thuật ô tô.xlsx -> Kỹ thuật ô tô.csv
# Đã chuyển đổi: Kỹ thuật hàng không.xlsx -> Kỹ thuật hàng không.csv
# Đã chuyển đổi: bảo dưỡng công nghiệp.xlsx -> bảo dưỡng công nghiệp.csv
# Đã chuyển đổi: PFIEV.xlsx -> PFIEV.csv
# Đã chuyển đổi: Kỹ thuật xây dựng công trình biển.xlsx -> Kỹ thuật xây dựng công trình biển.csv
# Đã chuyển đổi: Logistics và hệ thống công nghiệp.xlsx -> Logistics và hệ thống công nghiệp.csv
# Đã chuyển đổi: Kiến trúc.xlsx -> Kiến trúc.csv
# Đã chuyển đổi: Bảng các câu hỏi thường gặp (trừ phần 2).xlsx -> Bảng các câu hỏi thường gặp (trừ phần 2).csv
# Đã chuyển đổi: Thiết kế vi mạch.xlsx -> Thiết kế vi mạch.csv
# Đã chuyển đổi: Bảng câu hỏi thường gặp(PTN Trọng điểm Quốc gia Điều khiển kỹ thuật số và Kỹ thuật hệ thống).xlsx -> Bảng câu hỏi thường gặp(PTN Trọng điểm Quốc gia Điều khiển kỹ thuật số và Kỹ thuật hệ thống).csv
# Đã chuyển đổi: Kinh tế xây dựng.xlsx -> Kinh tế xây dựng.csv
# Đã chuyển đổi: Kỹ thuật hóa học.xlsx -> Kỹ thuật hóa học.csv
# Đã chuyển đổi: Quản lý tài nguyên và môi trường.xlsx -> Quản lý tài nguyên và môi trường.csv
# Đã chuyển đổi: Kỹ thuật xây dựng công trình giao thông.xlsx -> Kỹ thuật xây dựng công trình giao thông.csv
# Đã chuyển đổi: Công nghệ kỹ thuật vật liệu.xlsx -> Công nghệ kỹ thuật vật liệu.csv
# Đã chuyển đổi: Kỹ thuật môi trường.xlsx -> Kỹ thuật môi trường.csv
# Đã chuyển đổi: cơ kỹ thuật.xlsx -> cơ kỹ thuật.csv
# Đã chuyển đổi: Vật lý kỹ thuật.xlsx -> Vật lý kỹ thuật.csv
# Đã chuyển đổi: Kỹ thuật dệt.xlsx -> Kỹ thuật dệt.csv
# Đã chuyển đổi: Kỹ thuật điện.xlsx -> Kỹ thuật điện.csv
# Đã chuyển đổi: Kỹ thuật xây dựng.xlsx -> Kỹ thuật xây dựng.csv
# Đã chuyển đổi: Địa chất - dầu khí.xlsx -> Địa chất - dầu khí.csv
# Đã chuyển đổi: Kỹ thuật tàu thủy.xlsx -> Kỹ thuật tàu thủy.csv
# Đã chuyển đổi: Công nghệ sinh học.xlsx -> Công nghệ sinh học.csv
# Đã chuyển đổi: điều khiển và tự động hóa.xlsx -> điều khiển và tự động hóa.csv
# Đã chuyển đổi: công nghệ thực phẩm.xlsx -> công nghệ thực phẩm.csv
# Đã chuyển đổi: Kỹ thuật máy tính.xlsx -> Kỹ thuật máy tính.csv
# Đã chuyển đổi: Bảng câu hỏi thường gặp(thông tin các khoa và văn phòng đào tạo).xlsx -> Bảng câu hỏi thường gặp(thông tin các khoa và văn phòng đào tạo).csv
# Đã chuyển đổi: Quản lý công nghiệp.xlsx -> Quản lý công nghiệp.csv
# Đã chuyển đổi: kỹ thuật cơ khí.xlsx -> kỹ thuật cơ khí.csv
# Đã chuyển đổi: Xây dựng dân dụng.xlsx -> Xây dựng dân dụng.csv
# Đã chuyển đổi: Khoa học dữ liệu.xlsx -> Khoa học dữ liệu.csv
# Đã chuyển đổi: Bảng câu hỏi thường gặp(thông tin lãnh đạo các đơn vị).xlsx -> Bảng câu hỏi thường gặp(thông tin lãnh đạo các đơn vị).csv
# Đã chuyển đổi: kỹ thuật cơ điện tử.xlsx -> kỹ thuật cơ điện tử.csv
# Đã chuyển đổi: Kỹ thuật và quản lý nước đô thị.xlsx -> Kỹ thuật và quản lý nước đô thị.csv
# Đã chuyển đổi: Địa kỹ thuật xây dựng.xlsx -> Địa kỹ thuật xây dựng.csv
# Đã chuyển đổi: Kỹ thuật cơ sở hạ tầng.xlsx -> Kỹ thuật cơ sở hạ tầng.csv
# Đã chuyển đổi: Kỹ thuật nhiệt.xlsx -> Kỹ thuật nhiệt.csv
# Đã chuyển đổi: Kỹ thuật vật liệu.xlsx -> Kỹ thuật vật liệu.csv
# Đã chuyển đổi: Bảng câu hỏi thường gặp (phần 2)(thông tin tuyển sinh).xlsx -> Bảng câu hỏi thường gặp (phần 2)(thông tin tuyển sinh).csv
# Hoàn tất quá trình chuyển đổi!
